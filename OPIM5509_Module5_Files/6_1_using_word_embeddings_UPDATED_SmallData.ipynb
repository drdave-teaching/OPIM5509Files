# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/drdave-teaching/OPIM5509Files/blob/main/OPIM5509_Module5_Files/6_1_using_word_embeddings_UPDATED_SmallData.ipynb)

# %% [markdown]
# # Using word embeddings
#
# This notebook contains the second code sample found in Chapter 6, Section 1 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ---
#
#
# Another popular and powerful way to associate a vector with a word is the use of dense "word vectors", also called "word embeddings".
# While the vectors obtained through one-hot encoding are binary, sparse (mostly made of zeros) and very high-dimensional (same dimensionality as the
# number of words in the vocabulary), "word embeddings" are low-dimensional floating point vectors
# (i.e. "dense" vectors, as opposed to sparse vectors).
# Unlike word vectors obtained via one-hot encoding, word embeddings are learned from data.
# It is common to see word embeddings that are 256-dimensional, 512-dimensional, or 1024-dimensional when dealing with very large vocabularies.
# On the other hand, one-hot encoding words generally leads to vectors that are 20,000-dimensional or higher (capturing a vocabulary of 20,000
# token in this case). So, word embeddings pack more information into far fewer dimensions.

# %%
import keras
keras.__version__
# Out:
# '2.9.0'

# %%
# make sure you have updated all of the file
# paths or it won't run on your machine
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ![word embeddings vs. one hot encoding](https://s3.amazonaws.com/book.keras.io/img/ch6/word_embeddings.png)

# %% [markdown]
# There are two ways to obtain word embeddings:
#
# * Learn word embeddings jointly with the main task you care about (e.g. document classification or sentiment prediction).
# In this setup, you would start with random word vectors, then learn your word vectors in the same way that you learn the weights of a neural network.
# * Load into your model word embeddings that were pre-computed using a different machine learning task than the one you are trying to solve.
# These are called "pre-trained word embeddings".
#
# Let's take a look at both.

# %% [markdown]
# ## Learning word embeddings with the `Embedding` layer
#
#
# The simplest way to associate a dense vector to a word would be to pick the vector at random. The problem with this approach is that the
# resulting embedding space would have no structure: for instance, the words "accurate" and "exact" may end up with completely different
# embeddings, even though they are interchangeable in most sentences. It would be very difficult for a deep neural network to make sense of
# such a noisy, unstructured embedding space.
#
# To get a bit more abstract: the geometric relationships between word vectors should reflect the semantic relationships between these words.
# Word embeddings are meant to map human language into a geometric space. For instance, in a reasonable embedding space, we would expect
# synonyms to be embedded into similar word vectors, and in general we would expect the geometric distance (e.g. L2 distance) between any two
# word vectors to relate to the semantic distance of the associated words (words meaning very different things would be embedded to points
# far away from each other, while related words would be closer). Even beyond mere distance, we may want specific __directions__ in the
# embedding space to be meaningful.
#
# [...]
#
#
# In real-world word embedding spaces, common examples of meaningful geometric transformations are "gender vectors" and "plural vector". For
# instance, by adding a "female vector" to the vector "king", one obtain the vector "queen". By adding a "plural vector", one obtain "kings".
# Word embedding spaces typically feature thousands of such interpretable and potentially useful vectors.
#
# Is there some "ideal" word embedding space that would perfectly map human language and could be used for any natural language processing
# task? Possibly, but in any case, we have yet to compute anything of the sort. Also, there isn't such a thing as "human language", there are
# many different languages and they are not isomorphic, as a language is the reflection of a specific culture and a specific context. But more
# pragmatically, what makes a good word embedding space depends heavily on your task: the perfect word embedding space for an
# English-language movie review sentiment analysis model may look very different from the perfect embedding space for an English-language
# legal document classification model, because the importance of certain semantic relationships varies from task to task.
#
# It is thus reasonable to __learn__ a new embedding space with every new task. Thankfully, backpropagation makes this really easy, and Keras makes it
# even easier. It's just about learning the weights of a layer: the `Embedding` layer.

# %%
from keras.layers import Embedding

# The Embedding layer takes at least two arguments:
# the number of possible tokens, here 1000 (1 + maximum word index),
# and the dimensionality of the embeddings, here 64.
embedding_layer = Embedding(1000, 64)

# %% [markdown]
# The `Embedding` layer is best understood as a dictionary mapping integer indices (which stand for specific words) to dense vectors. It takes
# as input integers, it looks up these integers into an internal dictionary, and it returns the associated vectors. It's effectively a dictionary lookup.

# %% [markdown]
# The `Embedding` layer takes as input a 2D tensor of integers, of shape `(samples, sequence_length)`, where each entry is a sequence of
# integers. It can embed sequences of variable lengths, so for instance we could feed into our embedding layer above batches that could have
# shapes `(32, 10)` (batch of 32 sequences of length 10) or `(64, 15)` (batch of 64 sequences of length 15). All sequences in a batch must
# have the same length, though (since we need to pack them into a single tensor), so sequences that are shorter than others should be padded
# with zeros, and sequences that are longer should be truncated.
#
# This layer returns a 3D floating point tensor, of shape `(samples, sequence_length, embedding_dimensionality)`. Such a 3D tensor can then
# be processed by a RNN layer or a 1D convolution layer (both will be introduced in the next sections).
#
# When you instantiate an `Embedding` layer, its weights (its internal dictionary of token vectors) are initially random, just like with any
# other layer. During training, these word vectors will be gradually adjusted via backpropagation, structuring the space into something that the
# downstream model can exploit. Once fully trained, your embedding space will show a lot of structure -- a kind of structure specialized for
# the specific problem you were training your model for.
#
# Let's apply this idea to the IMDB movie review sentiment prediction task that you are already familiar with. Let's quickly prepare
# the data. We will restrict the movie reviews to the top 10,000 most common words (like we did the first time we worked with this dataset),
# and cut the reviews after only 20 words. Our network will simply learn 8-dimensional embeddings for each of the 10,000 words, turn the
# input integer sequences (2D integer tensor) into embedded sequences (3D float tensor), flatten the tensor to 2D, and train a single `Dense`
# layer on top for classification.

# %%
from keras.datasets import imdb
from keras import preprocessing
from keras.utils import pad_sequences

# Number of words to consider as features
max_features = 10000
# Cut texts after this number of words
# (among top max_features most common words)
maxlen = 20

# Load the data as lists of integers.
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

# This turns our lists of integers
# into a 2D integer tensor of shape `(samples, maxlen)`
x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)

# %%
from keras.models import Sequential
from keras.layers import Flatten, Dense

model = Sequential()
# We specify the maximum input length to our Embedding layer
# so we can later flatten the embedded inputs
model.add(Embedding(10000, 8, input_length=maxlen))
# After the Embedding layer,
# our activations have shape `(samples, maxlen, 8)`.

# We flatten the 3D tensor of embeddings
# into a 2D tensor of shape `(samples, maxlen * 8)`
model.add(Flatten())

# We add the classifier on top
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
model.summary()

history = model.fit(x_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_split=0.2)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 20, 8)             80000
#
#  flatten_3 (Flatten)         (None, 160)               0
#
#  dense_5 (Dense)             (None, 1)                 161
#
# =================================================================
# Total params: 80,161
# Trainable params: 80,161
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.6647 - acc: 0.6263 - val_loss: 0.6069 - val_acc: 0.6974
# Epoch 2/10
# 625/625 [==============================] - 4s 6ms/step - loss: 0.5324 - acc: 0.7526 - val_loss: 0.5205 - val_acc: 0.7312
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.4594 - acc: 0.7887 - val_loss: 0.4984 - val_acc: 0.7480
# Epoch 4/10
# 625/625 [==============================] - 4s 6ms/step - loss: 0.4241 - acc: 0.8061 - val_loss: 0.4942 - val_acc: 0.7518
# Epoch 5/10
# 625/625 [==============================] - 4s 6ms/step - loss: 0.4004 - acc: 0.8188 - val_loss: 0.4944 - val_acc: 0.7544
# Epoch 6/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3814 - acc: 0.8306 - val_loss: 0.4985 - val_acc: 0.7534
# Epoch 7/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3642 - acc: 0.8404 - val_loss: 0.5039 - val_acc: 0.7558
# Epoch 8/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3479 - acc: 0.8508 - val_loss: 0.5095 - val_acc: 0.7550
# Epoch 9/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3317 - acc: 0.8595 - val_loss: 0.5146 - val_acc: 0.7492
# Epoch 10/10
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3167 - acc: 0.8669 - val_loss: 0.5215 - val_acc: 0.7440

# %% [markdown]
# We get to a validation accuracy of ~76%, which is pretty good considering that we only look at the first 20 words in every review. But
# note that merely flattening the embedded sequences and training a single `Dense` layer on top leads to a model that treats each word in the
# input sequence separately, without considering inter-word relationships and structure sentence (e.g. it would likely treat both _"this movie
# is shit"_ and _"this movie is the shit"_ as being negative "reviews"). It would be much better to add recurrent layers or 1D convolutional
# layers on top of the embedded sequences to learn features that take into account each sequence as a whole. That's what we will focus on in
# the next few sections.

# %% [markdown]
# ## Using pre-trained word embeddings
#
#
# Sometimes, you have so little training data available that could never use your data alone to learn an appropriate task-specific embedding
# of your vocabulary. What to do then?
#
# Instead of learning word embeddings jointly with the problem you want to solve, you could be loading embedding vectors from a pre-computed
# embedding space known to be highly structured and to exhibit useful properties -- that captures generic aspects of language structure. The
# rationale behind using pre-trained word embeddings in natural language processing is very much the same as for using pre-trained convnets
# in image classification: we don't have enough data available to learn truly powerful features on our own, but we expect the features that
# we need to be fairly generic, i.e. common visual features or semantic features. In this case it makes sense to reuse features learned on a
# different problem.
#
# Such word embeddings are generally computed using word occurrence statistics (observations about what words co-occur in sentences or
# documents), using a variety of techniques, some involving neural networks, others not. The idea of a dense, low-dimensional embedding space
# for words, computed in an unsupervised way, was initially explored by Bengio et al. in the early 2000s, but it only started really taking
# off in research and industry applications after the release of one of the most famous and successful word embedding scheme: the Word2Vec
# algorithm, developed by Mikolov at Google in 2013. Word2Vec dimensions capture specific semantic properties, e.g. gender.
#
# There are various pre-computed databases of word embeddings that can download and start using in a Keras `Embedding` layer. Word2Vec is one
# of them. Another popular one is called "GloVe", developed by Stanford researchers in 2014. It stands for "Global Vectors for Word
# Representation", and it is an embedding technique based on factorizing a matrix of word co-occurrence statistics. Its developers have made
# available pre-computed embeddings for millions of English tokens, obtained from Wikipedia data or from Common Crawl data.
#
# Let's take a look at how you can get started using GloVe embeddings in a Keras model. The same method will of course be valid for Word2Vec
# embeddings or any other word embedding database that you can download. We will also use this example to refresh the text tokenization
# techniques we introduced a few paragraphs ago: we will start from raw text, and work our way up.

# %% [markdown]
# ## Putting it all together: from raw text to word embeddings
#
#
# We will be using a model similar to the one we just went over -- embedding sentences in sequences of vectors, flattening them and training a
# `Dense` layer on top. But we will do it using pre-trained word embeddings, and instead of using the pre-tokenized IMDB data packaged in
# Keras, we will start from scratch, by downloading the original text data.

# %% [markdown]
# ### Download the IMDB data as raw text
#
#
# First, head to `http://ai.stanford.edu/~amaas/data/sentiment/` and download the raw IMDB dataset (if the URL isn't working anymore, just
# Google "IMDB dataset"). Uncompress it.
#
# Now let's collect the individual training reviews into a list of strings, one string per review, and let's also collect the review labels
# (positive / negative) into a `labels` list:

# %%
# https://drive.google.com/file/d/1PB2kIxPos4QTQjhSqT3DJqqPUpxIxmuK/view?usp=sharing
# !gdown 1PB2kIxPos4QTQjhSqT3DJqqPUpxIxmuK
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1PB2kIxPos4QTQjhSqT3DJqqPUpxIxmuK
# From (redirected): https://drive.google.com/uc?id=1PB2kIxPos4QTQjhSqT3DJqqPUpxIxmuK&confirm=t&uuid=7658bb7e-ae39-4383-84b2-b83de629e578
# To: /content/aclImdb-20241107T205027Z-001.zip
# 100% 9.57M/9.57M [00:00<00:00, 119MB/s]

# %%
# prompt: unzip /content/aclImdb-20241107T205027Z-001.zip

# !unzip /content/aclImdb-20241107T205027Z-001.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: aclImdb/test/neg/1580_1.txt
#   inflating: aclImdb/test/neg/1578_4.txt
#   inflating: aclImdb/test/neg/1576_2.txt
#   inflating: aclImdb/test/neg/1574_1.txt
#   inflating: aclImdb/test/neg/1587_3.txt
#   inflating: aclImdb/test/neg/1584_1.txt
#   inflating: aclImdb/test/neg/1608_1.txt
#   inflating: aclImdb/test/neg/1604_1.txt
#   inflating: aclImdb/test/neg/1606_1.txt
#   inflating: aclImdb/test/neg/1588_3.txt
#   inflating: aclImdb/test/neg/156_3.txt
#   inflating: aclImdb/test/neg/1577_4.txt
#   inflating: aclImdb/test/neg/1569_3.txt
#   inflating: aclImdb/test/neg/1581_1.txt
#   inflating: aclImdb/test/neg/1570_2.txt
#   inflating: aclImdb/test/neg/1568_4.txt
#   inflating: aclImdb/test/neg/157_3.txt
#   inflating: aclImdb/test/neg/1565_4.txt
#   inflating: aclImdb/test/neg/1575_1.txt
#   inflating: aclImdb/test/neg/1566_4.txt
#   inflating: aclImdb/test/neg/1573_3.txt
#   inflating: aclImdb/test/neg/1589_1.txt
#   inflating: aclImdb/test/neg/1593_4.txt
#   inflating: aclImdb/test/neg/1554_1.txt
#   inflating: aclImdb/test/neg/1582_2.txt
#   inflating: aclImdb/test/neg/1598_1.txt
#   inflating: aclImdb/test/neg/1585_1.txt
#   inflating: aclImdb/test/neg/1564_1.txt
#   inflating: aclImdb/test/neg/1547_1.txt
#   inflating: aclImdb/test/neg/1567_1.txt
#   inflating: aclImdb/test/neg/158_1.txt
#   inflating: aclImdb/test/neg/1561_3.txt
#   inflating: aclImdb/test/neg/1543_3.txt
#   inflating: aclImdb/test/neg/1549_1.txt
#   inflating: aclImdb/test/neg/1552_1.txt
#   inflating: aclImdb/test/neg/1546_1.txt
#   inflating: aclImdb/test/neg/1559_2.txt
#   inflating: aclImdb/test/neg/1562_4.txt
#   inflating: aclImdb/test/neg/1571_4.txt
#   inflating: aclImdb/test/neg/154_2.txt
#   inflating: aclImdb/test/neg/1558_2.txt
#   inflating: aclImdb/test/neg/1556_1.txt
#   inflating: aclImdb/test/neg/1555_2.txt
#   inflating: aclImdb/test/neg/1550_2.txt
#   inflating: aclImdb/test/neg/1553_3.txt
#   inflating: aclImdb/test/neg/1586_1.txt
#   inflating: aclImdb/test/neg/1545_1.txt
#   inflating: aclImdb/test/neg/1557_2.txt
#   inflating: aclImdb/test/neg/1572_3.txt
#   inflating: aclImdb/test/neg/1540_3.txt
#   inflating: aclImdb/test/neg/1560_4.txt
#   inflating: aclImdb/test/neg/1563_2.txt
#   inflating: aclImdb/test/neg/1531_3.txt
#   inflating: aclImdb/test/neg/1535_3.txt
#   inflating: aclImdb/test/neg/1532_4.txt
#   inflating: aclImdb/test/neg/1523_4.txt
#   inflating: aclImdb/test/neg/1533_4.txt
#   inflating: aclImdb/test/neg/1544_3.txt
#   inflating: aclImdb/test/neg/1528_2.txt
#   inflating: aclImdb/test/neg/153_4.txt
#   inflating: aclImdb/test/neg/1551_4.txt
#   inflating: aclImdb/test/neg/1539_2.txt
#   inflating: aclImdb/test/neg/1548_1.txt
#   inflating: aclImdb/test/neg/1527_3.txt
#   inflating: aclImdb/test/neg/1538_2.txt
#   inflating: aclImdb/test/neg/152_4.txt
#   inflating: aclImdb/test/neg/1530_1.txt
#   inflating: aclImdb/test/neg/1542_3.txt
#   inflating: aclImdb/test/neg/1521_1.txt
#   inflating: aclImdb/test/neg/1534_4.txt
#   inflating: aclImdb/test/neg/1524_3.txt
#   inflating: aclImdb/test/neg/1515_1.txt
#   inflating: aclImdb/test/neg/1583_2.txt
#   inflating: aclImdb/test/neg/1504_1.txt
#   inflating: aclImdb/test/neg/1526_3.txt
#   inflating: aclImdb/test/neg/1525_1.txt
#   inflating: aclImdb/test/neg/1510_1.txt
#   inflating: aclImdb/test/neg/1501_1.txt
#   inflating: aclImdb/test/neg/1512_1.txt
#   inflating: aclImdb/test/neg/1505_3.txt
#   inflating: aclImdb/test/neg/1522_1.txt
#   inflating: aclImdb/test/neg/1500_2.txt
#   inflating: aclImdb/test/neg/1507_1.txt
#   inflating: aclImdb/test/neg/1536_3.txt
#   inflating: aclImdb/test/neg/1513_3.txt
#   inflating: aclImdb/test/neg/151_2.txt
#   inflating: aclImdb/test/neg/1518_1.txt
#   inflating: aclImdb/test/neg/1511_2.txt
#   inflating: aclImdb/test/neg/1729_1.txt
#   inflating: aclImdb/test/neg/1516_1.txt
#   inflating: aclImdb/test/neg/1517_1.txt
#   inflating: aclImdb/test/neg/1508_2.txt
#   inflating: aclImdb/test/neg/1502_1.txt
#   inflating: aclImdb/test/neg/1529_4.txt
#   inflating: aclImdb/test/neg/14_1.txt
#   inflating: aclImdb/test/neg/1491_1.txt
#   inflating: aclImdb/test/neg/1492_3.txt
#   inflating: aclImdb/test/neg/148_1.txt
#   inflating: aclImdb/test/neg/1497_1.txt
#   inflating: aclImdb/test/neg/1489_4.txt
#   inflating: aclImdb/test/neg/1520_2.txt
#   inflating: aclImdb/test/neg/1537_2.txt
#   inflating: aclImdb/test/neg/150_4.txt
#   inflating: aclImdb/test/neg/1488_4.txt
#   inflating: aclImdb/test/neg/1541_2.txt
#   inflating: aclImdb/test/neg/1495_1.txt
#   inflating: aclImdb/test/neg/1509_2.txt
#   inflating: aclImdb/test/neg/1499_3.txt
#   inflating: aclImdb/test/neg/1483_3.txt
#   inflating: aclImdb/test/neg/1493_4.txt
#   inflating: aclImdb/test/neg/1496_1.txt
#   inflating: aclImdb/test/neg/1486_4.txt
#   inflating: aclImdb/test/neg/1471_2.txt
#   inflating: aclImdb/test/neg/146_1.txt
#   inflating: aclImdb/test/neg/1478_4.txt
#   inflating: aclImdb/test/neg/1479_4.txt
#   inflating: aclImdb/test/neg/1485_3.txt
#   inflating: aclImdb/test/neg/1503_1.txt
#   inflating: aclImdb/test/neg/1514_1.txt
#   inflating: aclImdb/test/neg/1494_4.txt
#   inflating: aclImdb/test/neg/1473_3.txt
#   inflating: aclImdb/test/neg/1470_1.txt
#   inflating: aclImdb/test/neg/1475_1.txt
#   inflating: aclImdb/test/neg/149_1.txt
#   inflating: aclImdb/test/neg/147_4.txt
#   inflating: aclImdb/test/neg/1487_3.txt
#   inflating: aclImdb/test/neg/1498_1.txt
#   inflating: aclImdb/test/neg/1482_4.txt
#   inflating: aclImdb/test/neg/1490_3.txt
#   inflating: aclImdb/test/neg/1757_1.txt
#   inflating: aclImdb/test/neg/1481_1.txt
#   inflating: aclImdb/test/neg/1484_4.txt
#   inflating: aclImdb/test/neg/1469_1.txt
#   inflating: aclImdb/test/pos/10820_8.txt
#   inflating: aclImdb/test/pos/1081_10.txt
#   inflating: aclImdb/test/neg/1468_1.txt
#   inflating: aclImdb/test/pos/10826_10.txt
#   inflating: aclImdb/test/pos/10827_9.txt
#   inflating: aclImdb/test/neg/1460_2.txt
#   inflating: aclImdb/test/pos/10824_7.txt
#   inflating: aclImdb/test/neg/1477_4.txt
#   inflating: aclImdb/test/neg/1519_1.txt
#   inflating: aclImdb/test/pos/10825_7.txt
#   inflating: aclImdb/test/pos/10811_9.txt
#   inflating: aclImdb/test/pos/10822_8.txt
#   inflating: aclImdb/test/neg/1474_4.txt
#   inflating: aclImdb/test/neg/145_1.txt
#   inflating: aclImdb/test/neg/1464_1.txt
#   inflating: aclImdb/test/neg/1466_3.txt
#   inflating: aclImdb/test/pos/10819_9.txt
#   inflating: aclImdb/test/neg/1506_2.txt
#   inflating: aclImdb/test/neg/1480_1.txt
#   inflating: aclImdb/test/pos/10817_8.txt
#   inflating: aclImdb/test/neg/1472_1.txt
#   inflating: aclImdb/test/pos/10823_9.txt
#   inflating: aclImdb/test/pos/10828_9.txt
#   inflating: aclImdb/test/pos/10818_10.txt
#   inflating: aclImdb/test/neg/1465_3.txt
#   inflating: aclImdb/test/pos/10807_7.txt
#   inflating: aclImdb/test/neg/1462_1.txt
#   inflating: aclImdb/test/neg/1459_4.txt
#   inflating: aclImdb/test/pos/10810_8.txt
#   inflating: aclImdb/test/neg/1467_1.txt
#   inflating: aclImdb/test/neg/1463_4.txt
#   inflating: aclImdb/test/pos/10814_9.txt
#   inflating: aclImdb/test/pos/10790_10.txt
#   inflating: aclImdb/test/pos/10805_7.txt
#   inflating: aclImdb/test/pos/10803_9.txt
#   inflating: aclImdb/test/pos/10804_8.txt
#   inflating: aclImdb/test/pos/10809_10.txt
#   inflating: aclImdb/test/pos/10797_10.txt
#   inflating: aclImdb/test/pos/10791_9.txt
#   inflating: aclImdb/test/pos/10799_10.txt
#   inflating: aclImdb/test/pos/10800_8.txt
#   inflating: aclImdb/test/pos/1079_8.txt
#   inflating: aclImdb/test/pos/10786_7.txt
#   inflating: aclImdb/test/pos/10806_8.txt
#   inflating: aclImdb/test/pos/10795_10.txt
#   inflating: aclImdb/test/pos/10812_9.txt
#   inflating: aclImdb/test/neg/1476_3.txt
#   inflating: aclImdb/test/pos/10813_7.txt
#   inflating: aclImdb/test/pos/10816_10.txt
#   inflating: aclImdb/test/pos/10793_7.txt
#   inflating: aclImdb/test/pos/107_10.txt
#   inflating: aclImdb/test/pos/10801_10.txt
#   inflating: aclImdb/test/pos/10779_9.txt
#   inflating: aclImdb/test/pos/10777_9.txt
#   inflating: aclImdb/test/pos/1080_8.txt
#   inflating: aclImdb/test/pos/10808_8.txt
#   inflating: aclImdb/test/pos/10796_8.txt
#   inflating: aclImdb/test/pos/10787_10.txt
#   inflating: aclImdb/test/pos/10815_8.txt
#   inflating: aclImdb/test/pos/10781_10.txt
#   inflating: aclImdb/test/pos/10782_8.txt
#   inflating: aclImdb/test/pos/10770_7.txt
#   inflating: aclImdb/test/pos/10802_8.txt
#   inflating: aclImdb/test/pos/10792_8.txt
#   inflating: aclImdb/test/pos/10775_10.txt
#   inflating: aclImdb/test/pos/10773_7.txt
#   inflating: aclImdb/test/pos/10776_10.txt
#   inflating: aclImdb/test/pos/10789_8.txt
#   inflating: aclImdb/test/pos/10763_9.txt
#   inflating: aclImdb/test/pos/10755_9.txt
#   inflating: aclImdb/test/pos/10788_10.txt
#   inflating: aclImdb/test/pos/10780_7.txt
#   inflating: aclImdb/test/pos/10772_10.txt
#   inflating: aclImdb/test/pos/10752_7.txt
#   inflating: aclImdb/test/neg/1461_3.txt
#   inflating: aclImdb/test/pos/1078_9.txt
#   inflating: aclImdb/test/pos/10760_8.txt
#   inflating: aclImdb/test/pos/10756_7.txt
#   inflating: aclImdb/test/pos/10774_10.txt
#   inflating: aclImdb/test/pos/10753_8.txt
#   inflating: aclImdb/test/pos/1075_9.txt
#   inflating: aclImdb/test/pos/10757_10.txt
#   inflating: aclImdb/test/pos/10764_10.txt
#   inflating: aclImdb/test/pos/10778_10.txt
#   inflating: aclImdb/test/pos/10747_7.txt
#   inflating: aclImdb/test/pos/10744_8.txt
#   inflating: aclImdb/test/pos/10784_9.txt
#   inflating: aclImdb/test/pos/10749_8.txt
#   inflating: aclImdb/test/pos/1077_10.txt
#   inflating: aclImdb/test/pos/10785_10.txt
#   inflating: aclImdb/test/pos/10765_10.txt
#   inflating: aclImdb/test/pos/10766_8.txt
#   inflating: aclImdb/test/pos/10743_7.txt
#   inflating: aclImdb/test/pos/10754_8.txt
#   inflating: aclImdb/test/pos/10748_8.txt
#   inflating: aclImdb/test/pos/10759_9.txt
#   inflating: aclImdb/test/pos/10768_8.txt
#   inflating: aclImdb/test/pos/10794_10.txt
#   inflating: aclImdb/test/pos/10771_8.txt
#   inflating: aclImdb/test/pos/10798_10.txt
#   inflating: aclImdb/test/neg/155_2.txt
#   inflating: aclImdb/test/pos/10741_9.txt
#   inflating: aclImdb/test/pos/10761_8.txt
#   inflating: aclImdb/test/pos/10783_7.txt
#   inflating: aclImdb/test/pos/10730_10.txt
#   inflating: aclImdb/test/pos/10728_8.txt
#   inflating: aclImdb/test/pos/10734_8.txt
#   inflating: aclImdb/test/pos/1076_8.txt
#   inflating: aclImdb/test/pos/1073_8.txt
#   inflating: aclImdb/test/pos/10746_8.txt
#   inflating: aclImdb/test/pos/10738_8.txt
#   inflating: aclImdb/test/pos/10751_10.txt
#   inflating: aclImdb/test/pos/1074_7.txt
#   inflating: aclImdb/test/pos/1072_8.txt
#   inflating: aclImdb/test/pos/10721_7.txt
#   inflating: aclImdb/test/pos/10732_10.txt
#   inflating: aclImdb/test/pos/10742_10.txt
#   inflating: aclImdb/test/pos/10719_7.txt
#   inflating: aclImdb/test/pos/10731_9.txt
#   inflating: aclImdb/test/pos/10745_8.txt
#   inflating: aclImdb/test/pos/10727_9.txt
#   inflating: aclImdb/test/pos/10739_9.txt
#   inflating: aclImdb/test/pos/10737_9.txt
#   inflating: aclImdb/test/pos/10711_10.txt
#   inflating: aclImdb/test/pos/10769_7.txt
#   inflating: aclImdb/test/pos/10767_10.txt
#   inflating: aclImdb/test/pos/10724_10.txt
#   inflating: aclImdb/test/pos/10729_9.txt
#   inflating: aclImdb/test/pos/10716_8.txt
#   inflating: aclImdb/test/pos/10722_7.txt
#   inflating: aclImdb/test/pos/10708_9.txt
#   inflating: aclImdb/test/pos/10714_9.txt
#   inflating: aclImdb/test/pos/10723_9.txt
#   inflating: aclImdb/test/pos/10735_10.txt
#   inflating: aclImdb/test/pos/1071_9.txt
#   inflating: aclImdb/test/pos/1070_10.txt
#   inflating: aclImdb/test/pos/10717_9.txt
#   inflating: aclImdb/test/pos/10700_10.txt
#   inflating: aclImdb/test/pos/10710_10.txt
#   inflating: aclImdb/test/pos/10736_9.txt
#   inflating: aclImdb/test/pos/10707_9.txt
#   inflating: aclImdb/test/pos/10697_10.txt
#   inflating: aclImdb/test/pos/10695_10.txt
#   inflating: aclImdb/test/pos/10758_10.txt
#   inflating: aclImdb/test/pos/10750_7.txt
#   inflating: aclImdb/test/pos/10718_10.txt
#   inflating: aclImdb/test/pos/10715_9.txt
#   inflating: aclImdb/test/pos/10733_10.txt
#   inflating: aclImdb/test/pos/10705_10.txt
#   inflating: aclImdb/test/pos/10690_7.txt
#   inflating: aclImdb/test/pos/10689_10.txt
#   inflating: aclImdb/test/pos/10685_7.txt
#   inflating: aclImdb/test/pos/10686_7.txt
#   inflating: aclImdb/test/pos/10726_7.txt
#   inflating: aclImdb/test/pos/10704_10.txt
#   inflating: aclImdb/test/pos/10682_10.txt
#   inflating: aclImdb/test/pos/10694_10.txt
#   inflating: aclImdb/test/pos/10701_10.txt
#   inflating: aclImdb/test/pos/10713_10.txt
#   inflating: aclImdb/test/pos/10699_8.txt
#   inflating: aclImdb/test/pos/106_9.txt
#   inflating: aclImdb/test/pos/10688_10.txt
#   inflating: aclImdb/test/pos/10703_9.txt
#   inflating: aclImdb/test/pos/10683_8.txt
#   inflating: aclImdb/test/pos/10691_10.txt
#   inflating: aclImdb/test/pos/1068_10.txt
#   inflating: aclImdb/test/pos/10696_10.txt
#   inflating: aclImdb/test/pos/10678_7.txt
#   inflating: aclImdb/test/pos/10762_9.txt
#   inflating: aclImdb/test/pos/10740_10.txt
#   inflating: aclImdb/test/pos/10725_7.txt
#   inflating: aclImdb/test/pos/10675_8.txt
#   inflating: aclImdb/test/pos/10672_7.txt
#   inflating: aclImdb/test/pos/1069_10.txt
#   inflating: aclImdb/test/pos/10674_7.txt
#   inflating: aclImdb/test/neg/1709_1.txt
#   inflating: aclImdb/test/pos/10679_8.txt
#   inflating: aclImdb/test/pos/10720_8.txt
#   inflating: aclImdb/test/pos/10681_8.txt
#   inflating: aclImdb/test/neg/1705_4.txt
#   inflating: aclImdb/test/pos/10673_9.txt
#   inflating: aclImdb/test/pos/1067_9.txt
#   inflating: aclImdb/test/pos/1066_8.txt
#   inflating: aclImdb/test/pos/10680_7.txt
#   inflating: aclImdb/test/pos/10668_7.txt
#   inflating: aclImdb/test/pos/10687_7.txt
#   inflating: aclImdb/test/pos/10676_8.txt
#   inflating: aclImdb/test/neg/1701_1.txt
#   inflating: aclImdb/test/neg/1702_2.txt
#   inflating: aclImdb/test/neg/1691_1.txt
#   inflating: aclImdb/test/pos/10709_8.txt
#   inflating: aclImdb/test/neg/1700_1.txt
#   inflating: aclImdb/test/pos/10660_10.txt
#   inflating: aclImdb/test/pos/10662_10.txt
#   inflating: aclImdb/test/pos/10693_10.txt
#   inflating: aclImdb/test/pos/10698_8.txt
#   inflating: aclImdb/test/pos/10677_10.txt
#   inflating: aclImdb/test/pos/10671_9.txt
#   inflating: aclImdb/test/neg/1694_1.txt
#   inflating: aclImdb/test/pos/10712_8.txt
#   inflating: aclImdb/test/pos/10684_7.txt
#   inflating: aclImdb/test/neg/1699_4.txt
#   inflating: aclImdb/test/neg/1703_3.txt
#   inflating: aclImdb/test/neg/1695_3.txt
#   inflating: aclImdb/test/neg/169_4.txt
#   inflating: aclImdb/test/neg/1708_1.txt
#   inflating: aclImdb/test/pos/10663_10.txt
#   inflating: aclImdb/test/neg/1706_1.txt
#   inflating: aclImdb/test/neg/1693_4.txt
#   inflating: aclImdb/test/neg/1692_3.txt
#   inflating: aclImdb/test/neg/1718_2.txt
#   inflating: aclImdb/test/pos/10670_9.txt
#   inflating: aclImdb/test/pos/10664_9.txt
#   inflating: aclImdb/test/pos/10666_10.txt
#   inflating: aclImdb/test/neg/1690_1.txt
#   inflating: aclImdb/test/pos/10657_10.txt
#   inflating: aclImdb/test/neg/1710_1.txt
#   inflating: aclImdb/test/pos/10653_10.txt
#   inflating: aclImdb/test/pos/1065_9.txt
#   inflating: aclImdb/test/pos/10706_10.txt
#   inflating: aclImdb/test/pos/10702_10.txt
#   inflating: aclImdb/test/pos/10692_10.txt
#   inflating: aclImdb/test/pos/10669_7.txt
#   inflating: aclImdb/test/neg/1707_1.txt
#   inflating: aclImdb/test/pos/10652_9.txt
#   inflating: aclImdb/test/neg/16_1.txt
#   inflating: aclImdb/test/neg/1688_4.txt
#   inflating: aclImdb/test/pos/10665_10.txt
#   inflating: aclImdb/test/pos/10656_8.txt
#   inflating: aclImdb/test/neg/1689_1.txt
#   inflating: aclImdb/test/pos/10650_9.txt
#   inflating: aclImdb/test/pos/10655_10.txt
#   inflating: aclImdb/test/pos/10641_8.txt
#   inflating: aclImdb/test/pos/10646_10.txt
#   inflating: aclImdb/test/pos/10647_10.txt
#   inflating: aclImdb/test/pos/10654_8.txt
#   inflating: aclImdb/test/neg/1684_1.txt
#   inflating: aclImdb/test/pos/10661_9.txt
#   inflating: aclImdb/test/pos/10644_8.txt
#   inflating: aclImdb/test/neg/1687_4.txt
#   inflating: aclImdb/test/pos/10643_9.txt
#   inflating: aclImdb/test/neg/1697_2.txt
#   inflating: aclImdb/test/pos/10658_9.txt
#   inflating: aclImdb/test/pos/10651_9.txt
#   inflating: aclImdb/test/pos/10642_10.txt
#   inflating: aclImdb/test/neg/1685_1.txt
#   inflating: aclImdb/test/pos/1063_10.txt
#   inflating: aclImdb/test/pos/1064_8.txt
#   inflating: aclImdb/test/neg/1704_3.txt
#   inflating: aclImdb/test/neg/168_1.txt
#   inflating: aclImdb/test/pos/10630_7.txt
#   inflating: aclImdb/test/pos/11990_10.txt
#   inflating: aclImdb/test/pos/12427_8.txt
#   inflating: aclImdb/test/neg/1698_1.txt
#   inflating: aclImdb/test/pos/11093_10.txt
#   inflating: aclImdb/test/pos/10868_9.txt
#   inflating: aclImdb/test/pos/10659_10.txt
#   inflating: aclImdb/test/pos/10648_9.txt
#   inflating: aclImdb/test/neg/3091_4.txt
#   inflating: aclImdb/test/neg/1696_3.txt
#   inflating: aclImdb/test/pos/10645_10.txt
#   inflating: aclImdb/test/pos/10640_7.txt
#   inflating: aclImdb/test/neg/2169_2.txt
#   inflating: aclImdb/test/pos/10864_7.txt
#   inflating: aclImdb/test/pos/11995_7.txt
#   inflating: aclImdb/test/pos/10649_10.txt
#   inflating: aclImdb/test/pos/10634_8.txt
#   inflating: aclImdb/test/pos/12426_7.txt
#   inflating: aclImdb/test/pos/1109_10.txt
#   inflating: aclImdb/test/pos/11091_8.txt
#   inflating: aclImdb/test/neg/3358_4.txt
#   inflating: aclImdb/test/neg/2176_4.txt
#   inflating: aclImdb/test/neg/2175_1.txt
#   inflating: aclImdb/test/pos/11996_7.txt
#   inflating: aclImdb/test/pos/1241_7.txt
#   inflating: aclImdb/test/neg/3367_1.txt
#   inflating: aclImdb/test/neg/3352_4.txt
#   inflating: aclImdb/test/pos/10667_10.txt
#   inflating: aclImdb/test/neg/3092_3.txt
#   inflating: aclImdb/test/pos/11999_8.txt
#   inflating: aclImdb/test/pos/10869_7.txt
#   inflating: aclImdb/test/pos/11991_10.txt
#   inflating: aclImdb/test/pos/10871_7.txt
#   inflating: aclImdb/test/neg/3090_1.txt
#   inflating: aclImdb/test/neg/3087_1.txt
#   inflating: aclImdb/test/neg/3081_1.txt
#   inflating: aclImdb/test/pos/10632_9.txt
#   inflating: aclImdb/test/pos/11098_8.txt
#   inflating: aclImdb/test/neg/1682_2.txt
#   inflating: aclImdb/test/pos/10635_10.txt
#   inflating: aclImdb/test/pos/10870_8.txt
#   inflating: aclImdb/test/pos/10637_9.txt
#   inflating: aclImdb/test/neg/334_2.txt
#   inflating: aclImdb/test/neg/3360_1.txt
#   inflating: aclImdb/test/pos/11094_7.txt
#   inflating: aclImdb/test/pos/12418_7.txt
#   inflating: aclImdb/test/pos/10633_8.txt
#   inflating: aclImdb/test/neg/2166_1.txt
#   inflating: aclImdb/test/pos/1108_8.txt
#   inflating: aclImdb/test/neg/3348_3.txt
#   inflating: aclImdb/test/pos/11994_9.txt
#   inflating: aclImdb/test/neg/3082_2.txt
#   inflating: aclImdb/test/pos/11998_8.txt
#   inflating: aclImdb/test/pos/12421_8.txt
#   inflating: aclImdb/test/pos/1062_8.txt
#   inflating: aclImdb/test/neg/2165_4.txt
#   inflating: aclImdb/test/pos/10639_10.txt
#   inflating: aclImdb/test/pos/1198_10.txt
#   inflating: aclImdb/test/pos/11099_10.txt
#   inflating: aclImdb/test/pos/10861_10.txt
#   inflating: aclImdb/test/pos/10862_9.txt
#   inflating: aclImdb/test/pos/11089_7.txt
#   inflating: aclImdb/test/pos/12425_10.txt
#   inflating: aclImdb/test/neg/2167_2.txt
#   inflating: aclImdb/test/neg/3084_4.txt
#   inflating: aclImdb/test/neg/3089_2.txt
#   inflating: aclImdb/test/pos/10638_9.txt
#   inflating: aclImdb/test/neg/2159_1.txt
#   inflating: aclImdb/test/pos/12417_9.txt
#   inflating: aclImdb/test/pos/11085_7.txt
#   inflating: aclImdb/test/pos/12424_7.txt
#   inflating: aclImdb/test/pos/12419_8.txt
#   inflating: aclImdb/test/pos/10636_8.txt
#   inflating: aclImdb/test/neg/2153_1.txt
#   inflating: aclImdb/test/pos/10857_9.txt
#   inflating: aclImdb/test/pos/11989_8.txt
#   inflating: aclImdb/test/neg/3086_1.txt
#   inflating: aclImdb/test/neg/3351_4.txt
#   inflating: aclImdb/test/neg/2157_2.txt
#   inflating: aclImdb/test/pos/11978_10.txt
#   inflating: aclImdb/test/pos/12416_7.txt
#   inflating: aclImdb/test/pos/11988_10.txt
#   inflating: aclImdb/test/pos/12420_10.txt
#   inflating: aclImdb/test/pos/11083_7.txt
#   inflating: aclImdb/test/pos/1107_9.txt
#   inflating: aclImdb/test/neg/2155_1.txt
#   inflating: aclImdb/test/neg/2168_2.txt
#   inflating: aclImdb/test/neg/3357_4.txt
#   inflating: aclImdb/test/pos/11079_8.txt
#   inflating: aclImdb/test/neg/3349_4.txt
#   inflating: aclImdb/test/pos/11981_10.txt
#   inflating: aclImdb/test/neg/3085_4.txt
#   inflating: aclImdb/test/neg/3355_3.txt
#   inflating: aclImdb/test/pos/10860_10.txt
#   inflating: aclImdb/test/neg/3088_3.txt
#   inflating: aclImdb/test/pos/11086_8.txt
#   inflating: aclImdb/test/pos/12423_9.txt
#   inflating: aclImdb/test/neg/3083_2.txt
#   inflating: aclImdb/test/pos/1061_8.txt
#   inflating: aclImdb/test/pos/11082_8.txt
#   inflating: aclImdb/test/pos/1085_9.txt
#   inflating: aclImdb/test/neg/2158_1.txt
#   inflating: aclImdb/test/pos/10628_9.txt
#   inflating: aclImdb/test/pos/10858_10.txt
#   inflating: aclImdb/test/pos/12415_8.txt
#   inflating: aclImdb/test/pos/10627_9.txt
#   inflating: aclImdb/test/neg/2156_1.txt
#   inflating: aclImdb/test/neg/308_1.txt
#   inflating: aclImdb/test/pos/10856_10.txt
#   inflating: aclImdb/test/pos/11985_8.txt
#   inflating: aclImdb/test/neg/3354_2.txt
#   inflating: aclImdb/test/neg/3080_1.txt
#   inflating: aclImdb/test/pos/11084_7.txt
#   inflating: aclImdb/test/pos/11984_8.txt
#   inflating: aclImdb/test/pos/10854_10.txt
#   inflating: aclImdb/test/neg/2154_1.txt
#   inflating: aclImdb/test/pos/1240_9.txt
#   inflating: aclImdb/test/pos/1197_9.txt
#   inflating: aclImdb/test/pos/10629_10.txt
#   inflating: aclImdb/test/pos/12422_7.txt
#   inflating: aclImdb/test/pos/10622_10.txt
#   inflating: aclImdb/test/pos/11983_10.txt
#   inflating: aclImdb/test/neg/3356_3.txt
#   inflating: aclImdb/test/pos/10855_10.txt
#   inflating: aclImdb/test/neg/2164_4.txt
#   inflating: aclImdb/test/pos/10853_8.txt
#   inflating: aclImdb/test/pos/11979_10.txt
#   inflating: aclImdb/test/neg/3347_2.txt
#   inflating: aclImdb/test/pos/12414_8.txt
#   inflating: aclImdb/test/pos/10859_9.txt
#   inflating: aclImdb/test/pos/11088_7.txt
#   inflating: aclImdb/test/neg/3353_4.txt
#   inflating: aclImdb/test/neg/307_1.txt
#   inflating: aclImdb/test/pos/11080_10.txt
#   inflating: aclImdb/test/pos/10631_9.txt
#   inflating: aclImdb/test/neg/2163_1.txt
#   inflating: aclImdb/test/neg/215_4.txt
#   inflating: aclImdb/test/pos/10852_9.txt
#   inflating: aclImdb/test/pos/10624_10.txt
#   inflating: aclImdb/test/neg/3350_1.txt
#   inflating: aclImdb/test/pos/11987_10.txt
#   inflating: aclImdb/test/neg/3070_1.txt
#   inflating: aclImdb/test/pos/12413_9.txt
#   inflating: aclImdb/test/pos/10851_9.txt
#   inflating: aclImdb/test/pos/11081_10.txt
#   inflating: aclImdb/test/neg/306_1.txt
#   inflating: aclImdb/test/pos/10850_10.txt
#   inflating: aclImdb/test/pos/12411_8.txt
#   inflating: aclImdb/test/pos/11986_7.txt
#   inflating: aclImdb/test/neg/3342_3.txt
#   inflating: aclImdb/test/neg/3077_2.txt
#   inflating: aclImdb/test/pos/11982_9.txt
#   inflating: aclImdb/test/neg/2161_4.txt
#   inflating: aclImdb/test/pos/12412_7.txt
#   inflating: aclImdb/test/pos/11087_9.txt
#   inflating: aclImdb/test/pos/10625_8.txt
#   inflating: aclImdb/test/neg/3073_2.txt
#   inflating: aclImdb/test/neg/3339_4.txt
#   inflating: aclImdb/test/pos/11077_10.txt
#   inflating: aclImdb/test/pos/11078_8.txt
#   inflating: aclImdb/test/pos/10619_9.txt
#   inflating: aclImdb/test/pos/10620_9.txt
#   inflating: aclImdb/test/neg/3072_3.txt
#   inflating: aclImdb/test/neg/2160_2.txt
#   inflating: aclImdb/test/neg/333_3.txt
#   inflating: aclImdb/test/neg/3346_3.txt
#   inflating: aclImdb/test/pos/10848_9.txt
#   inflating: aclImdb/test/pos/12404_10.txt
#   inflating: aclImdb/test/pos/11070_8.txt
#   inflating: aclImdb/test/pos/10623_8.txt
#   inflating: aclImdb/test/pos/10843_10.txt
#   inflating: aclImdb/test/neg/2152_1.txt
#   inflating: aclImdb/test/neg/3075_1.txt
#   inflating: aclImdb/test/pos/11071_10.txt
#   inflating: aclImdb/test/pos/11971_8.txt
#   inflating: aclImdb/test/neg/3340_1.txt
#   inflating: aclImdb/test/pos/10621_10.txt
#   inflating: aclImdb/test/pos/12405_10.txt
#   inflating: aclImdb/test/pos/12408_10.txt
#   inflating: aclImdb/test/neg/2151_2.txt
#   inflating: aclImdb/test/neg/3341_4.txt
#   inflating: aclImdb/test/pos/11075_8.txt
#   inflating: aclImdb/test/neg/2150_1.txt
#   inflating: aclImdb/test/pos/10845_10.txt
#   inflating: aclImdb/test/pos/10626_8.txt
#   inflating: aclImdb/test/pos/11074_8.txt
#   inflating: aclImdb/test/pos/10618_10.txt
#   inflating: aclImdb/test/pos/10841_10.txt
#   inflating: aclImdb/test/pos/11972_7.txt
#   inflating: aclImdb/test/pos/12407_10.txt
#   inflating: aclImdb/test/neg/3079_2.txt
#   inflating: aclImdb/test/neg/3071_1.txt
#   inflating: aclImdb/test/pos/12410_10.txt
#   inflating: aclImdb/test/neg/3076_4.txt
#   inflating: aclImdb/test/pos/10842_10.txt
#   inflating: aclImdb/test/pos/12406_10.txt
#   inflating: aclImdb/test/neg/2144_4.txt
#   inflating: aclImdb/test/pos/11072_8.txt
#   inflating: aclImdb/test/pos/10617_8.txt
#   inflating: aclImdb/test/pos/11980_10.txt
#   inflating: aclImdb/test/neg/3344_1.txt
#   inflating: aclImdb/test/pos/10844_10.txt
#   inflating: aclImdb/test/pos/11073_7.txt
#   inflating: aclImdb/test/neg/3078_1.txt
#   inflating: aclImdb/test/pos/11976_10.txt
#   inflating: aclImdb/test/neg/3343_4.txt
#   inflating: aclImdb/test/neg/2146_3.txt
#   inflating: aclImdb/test/pos/11974_7.txt
#   inflating: aclImdb/test/pos/11975_8.txt
#   inflating: aclImdb/test/neg/3338_2.txt
#   inflating: aclImdb/test/neg/3337_1.txt
#   inflating: aclImdb/test/pos/11068_10.txt
#   inflating: aclImdb/test/neg/2141_1.txt
#   inflating: aclImdb/test/neg/3069_1.txt
#   inflating: aclImdb/test/pos/11970_10.txt
#   inflating: aclImdb/test/neg/3336_1.txt
#   inflating: aclImdb/test/neg/2149_3.txt
#   inflating: aclImdb/test/neg/3060_3.txt
#   inflating: aclImdb/test/pos/10846_10.txt
#   inflating: aclImdb/test/pos/10849_10.txt
#   inflating: aclImdb/test/pos/11973_10.txt
#   inflating: aclImdb/test/pos/10614_9.txt
#   inflating: aclImdb/test/pos/10611_7.txt
#   inflating: aclImdb/test/neg/3074_4.txt
#   inflating: aclImdb/test/neg/3345_3.txt
#   inflating: aclImdb/test/pos/10609_9.txt
#   inflating: aclImdb/test/pos/10847_10.txt
#   inflating: aclImdb/test/neg/2162_1.txt
#   inflating: aclImdb/test/pos/1106_9.txt
#   inflating: aclImdb/test/neg/3063_1.txt
#   inflating: aclImdb/test/neg/2148_1.txt
#   inflating: aclImdb/test/pos/12402_10.txt
#   inflating: aclImdb/test/neg/3334_1.txt
#   inflating: aclImdb/test/pos/11069_7.txt
#   inflating: aclImdb/test/neg/3335_2.txt
#   inflating: aclImdb/test/pos/10610_7.txt
#   inflating: aclImdb/test/neg/3332_3.txt
#   inflating: aclImdb/test/pos/11977_10.txt
#   inflating: aclImdb/test/pos/11067_10.txt
#   inflating: aclImdb/test/pos/12403_10.txt
#   inflating: aclImdb/test/pos/1084_8.txt
#   inflating: aclImdb/test/neg/2143_4.txt
#   inflating: aclImdb/test/pos/11066_7.txt
#   inflating: aclImdb/test/pos/1083_7.txt
#   inflating: aclImdb/test/neg/2809_3.txt
#   inflating: aclImdb/test/pos/1060_8.txt
#   inflating: aclImdb/test/pos/10612_9.txt
#   inflating: aclImdb/test/neg/3328_4.txt
#   inflating: aclImdb/test/neg/3062_2.txt
#   inflating: aclImdb/test/pos/10840_9.txt
#   inflating: aclImdb/test/neg/3329_4.txt
#   inflating: aclImdb/test/pos/11969_10.txt
#   inflating: aclImdb/test/pos/12409_10.txt
#   inflating: aclImdb/test/pos/10613_8.txt
#   inflating: aclImdb/test/neg/2147_4.txt
#   inflating: aclImdb/test/neg/214_1.txt
#   inflating: aclImdb/test/pos/1196_9.txt
#   inflating: aclImdb/test/neg/2145_3.txt
#   inflating: aclImdb/test/neg/1458_2.txt
#   inflating: aclImdb/test/pos/11076_10.txt
#   inflating: aclImdb/test/pos/10835_9.txt
#   inflating: aclImdb/test/pos/11960_7.txt
#   inflating: aclImdb/test/neg/3066_1.txt
#   inflating: aclImdb/test/neg/1457_1.txt
#   inflating: aclImdb/test/neg/3065_1.txt
#   inflating: aclImdb/test/pos/11968_8.txt
#   inflating: aclImdb/test/pos/11059_8.txt
#   inflating: aclImdb/test/pos/10616_10.txt
#   inflating: aclImdb/test/pos/10608_10.txt
#   inflating: aclImdb/test/neg/2804_3.txt
#   inflating: aclImdb/test/neg/2140_1.txt
#   inflating: aclImdb/test/neg/332_1.txt
#   inflating: aclImdb/test/pos/10834_10.txt
#   inflating: aclImdb/test/neg/3061_1.txt
#   inflating: aclImdb/test/pos/11063_10.txt
#   inflating: aclImdb/test/neg/144_2.txt
#   inflating: aclImdb/test/pos/10606_10.txt
#   inflating: aclImdb/test/pos/10837_10.txt
#   inflating: aclImdb/test/pos/11965_8.txt
#   inflating: aclImdb/test/pos/11962_8.txt
#   inflating: aclImdb/test/neg/1449_4.txt
#   inflating: aclImdb/test/pos/11060_7.txt
#   inflating: aclImdb/test/neg/2811_3.txt
#   inflating: aclImdb/test/pos/11064_8.txt
#   inflating: aclImdb/test/neg/3059_2.txt
#   inflating: aclImdb/test/pos/10615_8.txt
#   inflating: aclImdb/test/neg/3325_1.txt
#   inflating: aclImdb/test/pos/10607_7.txt
#   inflating: aclImdb/test/pos/11966_8.txt
#   inflating: aclImdb/test/neg/280_1.txt
#   inflating: aclImdb/test/pos/10831_7.txt
#   inflating: aclImdb/test/pos/1059_10.txt
#   inflating: aclImdb/test/neg/2139_1.txt
#   inflating: aclImdb/test/neg/2807_4.txt
#   inflating: aclImdb/test/pos/1105_10.txt
#   inflating: aclImdb/test/neg/1450_3.txt
#   inflating: aclImdb/test/pos/10836_9.txt
#   inflating: aclImdb/test/neg/213_3.txt
#   inflating: aclImdb/test/neg/3330_3.txt
#   inflating: aclImdb/test/neg/2142_4.txt
#   inflating: aclImdb/test/pos/11964_9.txt
#   inflating: aclImdb/test/neg/2803_1.txt
#   inflating: aclImdb/test/neg/3068_3.txt
#   inflating: aclImdb/test/pos/105_8.txt
#   inflating: aclImdb/test/pos/11058_8.txt
#   inflating: aclImdb/test/neg/3331_3.txt
#   inflating: aclImdb/test/pos/10586_9.txt
#   inflating: aclImdb/test/pos/10604_8.txt
#   inflating: aclImdb/test/pos/10597_10.txt
#   inflating: aclImdb/test/neg/2134_4.txt
#   inflating: aclImdb/test/pos/10605_10.txt
#   inflating: aclImdb/test/pos/10596_10.txt
#   inflating: aclImdb/test/pos/10602_8.txt
#   inflating: aclImdb/test/pos/10595_10.txt
#   inflating: aclImdb/test/pos/10590_9.txt
#   inflating: aclImdb/test/pos/10599_8.txt
#   inflating: aclImdb/test/pos/10588_10.txt
#   inflating: aclImdb/test/pos/10589_10.txt
#   inflating: aclImdb/test/pos/10591_10.txt
#   inflating: aclImdb/test/pos/10582_10.txt
#   inflating: aclImdb/test/pos/10587_10.txt
#   inflating: aclImdb/test/pos/10592_8.txt
#   inflating: aclImdb/test/neg/1454_4.txt
#   inflating: aclImdb/test/pos/10578_10.txt
#   inflating: aclImdb/test/pos/10576_9.txt
#   inflating: aclImdb/test/pos/10581_10.txt
#   inflating: aclImdb/test/pos/10577_9.txt
#   inflating: aclImdb/test/pos/10575_10.txt
#   inflating: aclImdb/test/pos/10580_10.txt
#   inflating: aclImdb/test/pos/10568_10.txt
#   inflating: aclImdb/test/pos/1057_8.txt
#   inflating: aclImdb/test/pos/10583_10.txt
#   inflating: aclImdb/test/pos/10598_10.txt
#   inflating: aclImdb/test/pos/10566_9.txt
#   inflating: aclImdb/test/pos/10570_10.txt
#   inflating: aclImdb/test/pos/10594_10.txt
#   inflating: aclImdb/test/neg/3064_1.txt
#   inflating: aclImdb/test/pos/10585_8.txt
#   inflating: aclImdb/test/pos/1058_10.txt
#   inflating: aclImdb/test/pos/10573_10.txt
#   inflating: aclImdb/test/pos/10558_9.txt
#   inflating: aclImdb/test/pos/10559_7.txt
#   inflating: aclImdb/test/pos/10593_8.txt
#   inflating: aclImdb/test/pos/10556_10.txt
#   inflating: aclImdb/test/pos/10571_10.txt
#   inflating: aclImdb/test/pos/10555_10.txt
#   inflating: aclImdb/test/pos/10572_10.txt
#   inflating: aclImdb/test/pos/10560_9.txt
#   inflating: aclImdb/test/pos/10567_8.txt
#   inflating: aclImdb/test/pos/10561_9.txt
#   inflating: aclImdb/test/pos/10551_10.txt
#   inflating: aclImdb/test/pos/10548_10.txt
#   inflating: aclImdb/test/pos/10579_10.txt
#   inflating: aclImdb/test/pos/10552_7.txt
#   inflating: aclImdb/test/pos/10565_10.txt
#   inflating: aclImdb/test/pos/10544_10.txt
#   inflating: aclImdb/test/pos/10554_9.txt
#   inflating: aclImdb/test/pos/10553_7.txt
#   inflating: aclImdb/test/pos/10584_8.txt
#   inflating: aclImdb/test/pos/10546_10.txt
#   inflating: aclImdb/test/pos/10563_9.txt
#   inflating: aclImdb/test/pos/1055_10.txt
#   inflating: aclImdb/test/pos/1056_8.txt
#   inflating: aclImdb/test/pos/10574_10.txt
#   inflating: aclImdb/test/pos/1053_10.txt
#   inflating: aclImdb/test/pos/10527_10.txt
#   inflating: aclImdb/test/pos/10549_10.txt
#   inflating: aclImdb/test/pos/10531_10.txt
#   inflating: aclImdb/test/pos/10557_8.txt
#   inflating: aclImdb/test/pos/10526_10.txt
#   inflating: aclImdb/test/pos/10530_10.txt
#   inflating: aclImdb/test/pos/10564_7.txt
#   inflating: aclImdb/test/pos/10545_10.txt
#   inflating: aclImdb/test/pos/10550_8.txt
#   inflating: aclImdb/test/pos/10537_9.txt
#   inflating: aclImdb/test/pos/10542_10.txt
#   inflating: aclImdb/test/pos/10547_10.txt
#   inflating: aclImdb/test/pos/10543_7.txt
#   inflating: aclImdb/test/pos/10533_10.txt
#   inflating: aclImdb/test/pos/10520_10.txt
#   inflating: aclImdb/test/pos/1051_10.txt
#   inflating: aclImdb/test/pos/10513_7.txt
#   inflating: aclImdb/test/pos/10528_8.txt
#   inflating: aclImdb/test/pos/10536_8.txt
#   inflating: aclImdb/test/pos/10505_7.txt
#   inflating: aclImdb/test/pos/10535_10.txt
#   inflating: aclImdb/test/pos/10532_9.txt
#   inflating: aclImdb/test/pos/1054_9.txt
#   inflating: aclImdb/test/pos/10534_10.txt
#   inflating: aclImdb/test/pos/10538_10.txt
#   inflating: aclImdb/test/pos/10569_7.txt
#   inflating: aclImdb/test/pos/10529_7.txt
#   inflating: aclImdb/test/pos/10541_8.txt
#   inflating: aclImdb/test/pos/10512_9.txt
#   inflating: aclImdb/test/pos/10516_10.txt
#   inflating: aclImdb/test/pos/10519_8.txt
#   inflating: aclImdb/test/pos/1052_10.txt
#   inflating: aclImdb/test/pos/10525_7.txt
#   inflating: aclImdb/test/pos/10522_10.txt
#   inflating: aclImdb/test/pos/10509_8.txt
#   inflating: aclImdb/test/pos/10506_8.txt
#   inflating: aclImdb/test/pos/10521_10.txt
#   inflating: aclImdb/test/pos/10524_10.txt
#   inflating: aclImdb/test/pos/10514_9.txt
#   inflating: aclImdb/test/pos/10517_10.txt
#   inflating: aclImdb/test/pos/10504_7.txt
#   inflating: aclImdb/test/pos/10508_7.txt
#   inflating: aclImdb/test/pos/104_10.txt
#   inflating: aclImdb/test/pos/10500_7.txt
#   inflating: aclImdb/test/pos/10539_8.txt
#   inflating: aclImdb/test/pos/10515_8.txt
#   inflating: aclImdb/test/pos/10491_7.txt
#   inflating: aclImdb/test/pos/10490_9.txt
#   inflating: aclImdb/test/pos/10489_8.txt
#   inflating: aclImdb/test/pos/10498_10.txt
#   inflating: aclImdb/test/pos/10523_9.txt
#   inflating: aclImdb/test/pos/1049_9.txt
#   inflating: aclImdb/test/pos/10511_10.txt
#   inflating: aclImdb/test/pos/10518_7.txt
#   inflating: aclImdb/test/pos/10497_10.txt
#   inflating: aclImdb/test/pos/10488_7.txt
#   inflating: aclImdb/test/pos/10492_8.txt
#   inflating: aclImdb/test/pos/10477_9.txt
#   inflating: aclImdb/test/pos/10496_10.txt
#   inflating: aclImdb/test/pos/10485_10.txt
#   inflating: aclImdb/test/pos/10484_10.txt
#   inflating: aclImdb/test/pos/10478_10.txt
#   inflating: aclImdb/test/pos/10481_9.txt
#   inflating: aclImdb/test/pos/10493_10.txt
#   inflating: aclImdb/test/pos/10499_8.txt
#   inflating: aclImdb/test/pos/10507_7.txt
#   inflating: aclImdb/test/pos/10501_10.txt
#   inflating: aclImdb/test/pos/10562_7.txt
#   inflating: aclImdb/test/pos/10494_8.txt
#   inflating: aclImdb/test/pos/10495_8.txt
#   inflating: aclImdb/test/pos/1048_8.txt
#   inflating: aclImdb/test/pos/1047_8.txt
#   inflating: aclImdb/test/pos/10480_8.txt
#   inflating: aclImdb/test/pos/10510_7.txt
#   inflating: aclImdb/test/pos/10475_10.txt
#   inflating: aclImdb/test/pos/10482_10.txt
#   inflating: aclImdb/test/pos/10467_9.txt
#   inflating: aclImdb/test/pos/10479_10.txt
#   inflating: aclImdb/test/pos/1050_9.txt
#   inflating: aclImdb/test/pos/10468_10.txt
#   inflating: aclImdb/test/pos/10540_10.txt
#   inflating: aclImdb/test/pos/10471_10.txt
#   inflating: aclImdb/test/pos/10472_10.txt
#   inflating: aclImdb/test/pos/10458_7.txt
#   inflating: aclImdb/test/pos/10483_8.txt
#   inflating: aclImdb/test/pos/10465_10.txt
#   inflating: aclImdb/test/pos/1045_9.txt
#   inflating: aclImdb/test/pos/10502_7.txt
#   inflating: aclImdb/test/pos/10487_7.txt
#   inflating: aclImdb/test/pos/10460_10.txt
#   inflating: aclImdb/test/pos/10461_10.txt
#   inflating: aclImdb/test/pos/10470_10.txt
#   inflating: aclImdb/test/pos/10486_10.txt
#   inflating: aclImdb/test/pos/10476_10.txt
#   inflating: aclImdb/test/pos/10457_8.txt
#   inflating: aclImdb/test/pos/10459_10.txt
#   inflating: aclImdb/test/pos/10451_7.txt
#   inflating: aclImdb/test/pos/10463_10.txt
#   inflating: aclImdb/test/pos/10444_9.txt
#   inflating: aclImdb/test/pos/10473_10.txt
#   inflating: aclImdb/test/pos/10442_8.txt
#   inflating: aclImdb/test/pos/10446_10.txt
#   inflating: aclImdb/test/pos/10454_8.txt
#   inflating: aclImdb/test/pos/10437_9.txt
#   inflating: aclImdb/test/pos/10453_10.txt
#   inflating: aclImdb/test/pos/10441_9.txt
#   inflating: aclImdb/test/pos/1043_9.txt
#   inflating: aclImdb/test/pos/10466_8.txt
#   inflating: aclImdb/test/pos/10427_10.txt
#   inflating: aclImdb/test/pos/10474_10.txt
#   inflating: aclImdb/test/pos/10449_10.txt
#   inflating: aclImdb/test/pos/10455_9.txt
#   inflating: aclImdb/test/pos/10464_10.txt
#   inflating: aclImdb/test/pos/10450_7.txt
#   inflating: aclImdb/test/pos/10433_8.txt
#   inflating: aclImdb/test/pos/10443_7.txt
#   inflating: aclImdb/test/pos/10469_10.txt
#   inflating: aclImdb/test/pos/10447_7.txt
#   inflating: aclImdb/test/pos/10439_8.txt
#   inflating: aclImdb/test/pos/10438_9.txt
#   inflating: aclImdb/test/pos/10434_8.txt
#   inflating: aclImdb/test/pos/10503_8.txt
#   inflating: aclImdb/test/pos/10429_9.txt
#   inflating: aclImdb/test/pos/1046_9.txt
#   inflating: aclImdb/test/pos/10448_7.txt
#   inflating: aclImdb/test/pos/10445_10.txt
#   inflating: aclImdb/test/pos/10462_10.txt
#   inflating: aclImdb/test/pos/10432_10.txt
#   inflating: aclImdb/test/pos/10456_10.txt
#   inflating: aclImdb/test/pos/10422_9.txt
#   inflating: aclImdb/test/pos/10412_8.txt
#   inflating: aclImdb/test/pos/10423_9.txt
#   inflating: aclImdb/test/pos/10440_7.txt
#   inflating: aclImdb/test/pos/10421_8.txt
#   inflating: aclImdb/test/pos/10436_8.txt
#   inflating: aclImdb/test/pos/10431_10.txt
#   inflating: aclImdb/test/pos/1041_10.txt
#   inflating: aclImdb/test/pos/10430_10.txt
#   inflating: aclImdb/test/pos/10419_8.txt
#   inflating: aclImdb/test/pos/1042_7.txt
#   inflating: aclImdb/test/pos/10435_7.txt
#   inflating: aclImdb/test/pos/10414_10.txt
#   inflating: aclImdb/test/pos/10425_10.txt
#   inflating: aclImdb/test/pos/10413_8.txt
#   inflating: aclImdb/test/pos/10416_9.txt
#   inflating: aclImdb/test/pos/10401_7.txt
#   inflating: aclImdb/test/pos/10410_10.txt
#   inflating: aclImdb/test/pos/1044_8.txt
#   inflating: aclImdb/test/pos/10424_7.txt
#   inflating: aclImdb/test/pos/10452_8.txt
#   inflating: aclImdb/test/pos/10417_7.txt
#   inflating: aclImdb/test/pos/10408_10.txt
#   inflating: aclImdb/test/pos/10407_10.txt
#   inflating: aclImdb/test/pos/10400_9.txt
#   inflating: aclImdb/test/pos/10391_9.txt
#   inflating: aclImdb/test/neg/12486_1.txt
#   inflating: aclImdb/test/pos/10405_7.txt
#   inflating: aclImdb/test/neg/12477_2.txt
#   inflating: aclImdb/test/pos/10428_10.txt
#   inflating: aclImdb/test/pos/10426_8.txt
#   inflating: aclImdb/test/pos/10411_10.txt
#   inflating: aclImdb/test/pos/1040_9.txt
#   inflating: aclImdb/test/pos/10402_8.txt
#   inflating: aclImdb/test/pos/10393_9.txt
#   inflating: aclImdb/test/pos/10415_7.txt
#   inflating: aclImdb/test/neg/1247_1.txt
#   inflating: aclImdb/test/pos/10395_10.txt
#   inflating: aclImdb/test/pos/10406_8.txt
#   inflating: aclImdb/test/pos/10403_10.txt
#   inflating: aclImdb/test/pos/10397_10.txt
#   inflating: aclImdb/test/pos/10404_9.txt
#   inflating: aclImdb/test/neg/12466_4.txt
#   inflating: aclImdb/test/pos/1038_10.txt
#   inflating: aclImdb/test/pos/10390_7.txt
#   inflating: aclImdb/test/neg/12472_1.txt
#   inflating: aclImdb/test/pos/10381_8.txt
#   inflating: aclImdb/test/neg/12471_3.txt
#   inflating: aclImdb/test/pos/10409_10.txt
#   inflating: aclImdb/test/pos/103_10.txt
#   inflating: aclImdb/test/pos/10392_8.txt
#   inflating: aclImdb/test/pos/1039_10.txt
#   inflating: aclImdb/test/neg/12478_4.txt
#   inflating: aclImdb/test/pos/10399_10.txt
#   inflating: aclImdb/test/neg/12479_4.txt
#   inflating: aclImdb/test/neg/12483_4.txt
#   inflating: aclImdb/test/neg/12480_2.txt
#   inflating: aclImdb/test/pos/10386_7.txt
#   inflating: aclImdb/test/neg/12487_2.txt
#   inflating: aclImdb/test/pos/10394_9.txt
#   inflating: aclImdb/test/pos/10383_8.txt
#   inflating: aclImdb/test/neg/12474_4.txt
#   inflating: aclImdb/test/pos/10388_10.txt
#   inflating: aclImdb/test/neg/12465_2.txt
#   inflating: aclImdb/test/neg/12467_2.txt
#   inflating: aclImdb/test/neg/12475_2.txt
#   inflating: aclImdb/test/pos/10420_9.txt
#   inflating: aclImdb/test/pos/10382_10.txt
#   inflating: aclImdb/test/neg/1246_1.txt
#   inflating: aclImdb/test/pos/10396_8.txt
#   inflating: aclImdb/test/pos/10389_7.txt
#   inflating: aclImdb/test/pos/10398_10.txt
#   inflating: aclImdb/test/neg/12473_3.txt
#   inflating: aclImdb/test/neg/12476_4.txt
#   inflating: aclImdb/test/pos/10384_7.txt
#   inflating: aclImdb/test/neg/12462_1.txt
#   inflating: aclImdb/test/neg/1245_2.txt
#   inflating: aclImdb/test/pos/1037_10.txt
#   inflating: aclImdb/test/neg/12468_1.txt
#   inflating: aclImdb/test/neg/12464_1.txt
#   inflating: aclImdb/test/neg/12456_1.txt
#   inflating: aclImdb/test/neg/12461_1.txt
#   inflating: aclImdb/test/neg/12463_1.txt
#   inflating: aclImdb/test/neg/12459_1.txt
#   inflating: aclImdb/test/neg/12460_2.txt
#   inflating: aclImdb/test/neg/12455_2.txt
#   inflating: aclImdb/test/neg/12454_1.txt
#   inflating: aclImdb/test/neg/12447_4.txt
#   inflating: aclImdb/test/neg/12451_3.txt
#   inflating: aclImdb/test/pos/10418_8.txt
#   inflating: aclImdb/test/pos/10379_9.txt
#   inflating: aclImdb/test/neg/12448_2.txt
#   inflating: aclImdb/test/neg/12452_3.txt
#   inflating: aclImdb/test/neg/12449_2.txt
#   inflating: aclImdb/test/pos/10385_10.txt
#   inflating: aclImdb/test/neg/1244_1.txt
#   inflating: aclImdb/test/neg/12442_1.txt
#   inflating: aclImdb/test/neg/12436_1.txt
#   inflating: aclImdb/test/neg/12439_1.txt
#   inflating: aclImdb/test/neg/12453_2.txt
#   inflating: aclImdb/test/neg/12431_4.txt
#   inflating: aclImdb/test/neg/12458_1.txt
#   inflating: aclImdb/test/pos/10387_9.txt
#   inflating: aclImdb/test/pos/10378_8.txt
#   inflating: aclImdb/test/neg/12445_1.txt
#   inflating: aclImdb/test/neg/12435_2.txt
#   inflating: aclImdb/test/neg/12444_1.txt
#   inflating: aclImdb/test/neg/12469_1.txt
#   inflating: aclImdb/test/neg/12443_1.txt
#   inflating: aclImdb/test/neg/12446_1.txt
#   inflating: aclImdb/test/neg/12470_3.txt
#   inflating: aclImdb/test/neg/12450_3.txt
#   inflating: aclImdb/test/neg/12433_1.txt
#   inflating: aclImdb/test/neg/12424_4.txt
#   inflating: aclImdb/test/neg/12441_2.txt
#   inflating: aclImdb/test/neg/12434_1.txt
#   inflating: aclImdb/test/neg/12437_1.txt
#   inflating: aclImdb/test/pos/10377_8.txt
#   inflating: aclImdb/test/pos/10369_9.txt
#   inflating: aclImdb/test/neg/12429_1.txt
#   inflating: aclImdb/test/neg/1243_2.txt
#   inflating: aclImdb/test/neg/12432_1.txt
#   inflating: aclImdb/test/pos/10367_8.txt
#   inflating: aclImdb/test/neg/12428_1.txt
#   inflating: aclImdb/test/pos/10380_7.txt
#   inflating: aclImdb/test/neg/12457_3.txt
#   inflating: aclImdb/test/neg/12425_3.txt
#   inflating: aclImdb/test/pos/10370_10.txt
#   inflating: aclImdb/test/pos/10376_10.txt
#   inflating: aclImdb/test/pos/10368_8.txt
#   inflating: aclImdb/test/neg/12423_2.txt
#   inflating: aclImdb/test/neg/12438_1.txt
#   inflating: aclImdb/test/neg/12418_3.txt
#   inflating: aclImdb/test/neg/12413_2.txt
#   inflating: aclImdb/test/pos/10371_8.txt
#   inflating: aclImdb/test/neg/1242_1.txt
#   inflating: aclImdb/test/neg/12414_1.txt
#   inflating: aclImdb/test/pos/10372_10.txt
#   inflating: aclImdb/test/pos/10373_10.txt
#   inflating: aclImdb/test/neg/12411_1.txt
#   inflating: aclImdb/test/neg/12416_2.txt
#   inflating: aclImdb/test/neg/12426_3.txt
#   inflating: aclImdb/test/neg/12421_3.txt
#   inflating: aclImdb/test/neg/12427_1.txt
#   inflating: aclImdb/test/pos/10356_7.txt
#   inflating: aclImdb/test/neg/12420_2.txt
#   inflating: aclImdb/test/pos/1036_10.txt
#   inflating: aclImdb/test/neg/12440_4.txt
#   inflating: aclImdb/test/pos/10374_10.txt
#   inflating: aclImdb/test/pos/10363_7.txt
#   inflating: aclImdb/test/neg/12419_1.txt
#   inflating: aclImdb/test/pos/10375_8.txt
#   inflating: aclImdb/test/neg/12430_1.txt
#   inflating: aclImdb/test/pos/10361_9.txt
#   inflating: aclImdb/test/pos/10366_8.txt
#   inflating: aclImdb/test/pos/10362_7.txt
#   inflating: aclImdb/test/pos/10358_7.txt
#   inflating: aclImdb/test/pos/10365_7.txt
#   inflating: aclImdb/test/neg/12410_3.txt
#   inflating: aclImdb/test/pos/10364_10.txt
#   inflating: aclImdb/test/neg/12422_1.txt
#   inflating: aclImdb/test/neg/12406_1.txt
#   inflating: aclImdb/test/neg/12404_4.txt
#   inflating: aclImdb/test/neg/1240_1.txt
#   inflating: aclImdb/test/neg/12417_4.txt
#   inflating: aclImdb/test/pos/1035_9.txt
#   inflating: aclImdb/test/neg/12408_4.txt
#   inflating: aclImdb/test/neg/12415_2.txt
#   inflating: aclImdb/test/pos/10355_10.txt
#   inflating: aclImdb/test/neg/12403_1.txt
#   inflating: aclImdb/test/neg/12412_3.txt
#   inflating: aclImdb/test/pos/10345_7.txt
#   inflating: aclImdb/test/pos/10357_7.txt
#   inflating: aclImdb/test/neg/12402_3.txt
#   inflating: aclImdb/test/neg/12409_4.txt
#   inflating: aclImdb/test/neg/12392_4.txt
#   inflating: aclImdb/test/neg/12407_1.txt
#   inflating: aclImdb/test/neg/12390_4.txt
#   inflating: aclImdb/test/pos/10354_7.txt
#   inflating: aclImdb/test/pos/10346_9.txt
#   inflating: aclImdb/test/neg/1241_4.txt
#   inflating: aclImdb/test/pos/1034_10.txt
#   inflating: aclImdb/test/neg/12401_4.txt
#   inflating: aclImdb/test/pos/10349_8.txt
#   inflating: aclImdb/test/pos/10351_8.txt
#   inflating: aclImdb/test/pos/10347_10.txt
#   inflating: aclImdb/test/neg/123_4.txt
#   inflating: aclImdb/test/pos/10350_9.txt
#   inflating: aclImdb/test/neg/12391_2.txt
#   inflating: aclImdb/test/pos/10359_8.txt
#   inflating: aclImdb/test/pos/10334_7.txt
#   inflating: aclImdb/test/neg/12395_1.txt
#   inflating: aclImdb/test/neg/12393_1.txt
#   inflating: aclImdb/test/neg/1239_4.txt
#   inflating: aclImdb/test/pos/10360_9.txt
#   inflating: aclImdb/test/pos/10337_10.txt
#   inflating: aclImdb/test/neg/12397_1.txt
#   inflating: aclImdb/test/neg/12399_4.txt
#   inflating: aclImdb/test/pos/10339_8.txt
#   inflating: aclImdb/test/pos/10344_9.txt
#   inflating: aclImdb/test/pos/10338_9.txt
#   inflating: aclImdb/test/neg/12384_4.txt
#   inflating: aclImdb/test/pos/10352_10.txt
#   inflating: aclImdb/test/pos/10341_7.txt
#   inflating: aclImdb/test/neg/12400_1.txt
#   inflating: aclImdb/test/neg/12382_4.txt
#   inflating: aclImdb/test/pos/10348_10.txt
#   inflating: aclImdb/test/neg/12383_2.txt
#   inflating: aclImdb/test/neg/12398_1.txt
#   inflating: aclImdb/test/neg/12386_2.txt
#   inflating: aclImdb/test/pos/10353_10.txt
#   inflating: aclImdb/test/pos/10343_9.txt
#   inflating: aclImdb/test/pos/10340_7.txt
#   inflating: aclImdb/test/neg/12388_3.txt
#   inflating: aclImdb/test/neg/12381_3.txt
#   inflating: aclImdb/test/pos/10336_7.txt
# ...
#   inflating: aclImdb/test/pos/10193_7.txt
#   inflating: aclImdb/test/neg/1314_1.txt
#   inflating: aclImdb/test/pos/11618_10.txt
#   inflating: aclImdb/test/pos/11615_8.txt
#   inflating: aclImdb/test/pos/11616_7.txt
#   inflating: aclImdb/test/neg/2667_3.txt
#   inflating: aclImdb/test/neg/1311_2.txt
#   inflating: aclImdb/test/pos/10196_8.txt
#   inflating: aclImdb/test/neg/1309_2.txt
#   inflating: aclImdb/test/pos/10191_10.txt
#   inflating: aclImdb/test/pos/10194_7.txt
#   inflating: aclImdb/test/neg/2663_1.txt
#   inflating: aclImdb/test/neg/2670_3.txt
#   inflating: aclImdb/test/pos/1019_10.txt
#   inflating: aclImdb/test/neg/1308_3.txt
#   inflating: aclImdb/test/neg/2666_4.txt
#   inflating: aclImdb/test/pos/11617_8.txt
#   inflating: aclImdb/test/neg/1307_1.txt
#   inflating: aclImdb/test/neg/2669_3.txt
#   inflating: aclImdb/test/neg/2665_3.txt
#   inflating: aclImdb/test/pos/10192_10.txt
#   inflating: aclImdb/test/neg/2664_4.txt
#   inflating: aclImdb/test/pos/11621_8.txt
#   inflating: aclImdb/test/neg/1310_2.txt
#   inflating: aclImdb/test/neg/2660_3.txt
#   inflating: aclImdb/test/neg/1306_1.txt
#   inflating: aclImdb/test/pos/1161_10.txt
#   inflating: aclImdb/test/neg/2661_4.txt
#   inflating: aclImdb/test/neg/130_4.txt
#   inflating: aclImdb/test/neg/265_1.txt
#   inflating: aclImdb/test/pos/10190_10.txt
#   inflating: aclImdb/test/neg/1305_1.txt
#   inflating: aclImdb/test/neg/1303_3.txt
#   inflating: aclImdb/test/pos/11620_8.txt
#   inflating: aclImdb/test/neg/1313_3.txt
#   inflating: aclImdb/test/neg/2648_2.txt
#   inflating: aclImdb/test/pos/10182_10.txt
#   inflating: aclImdb/test/pos/10186_10.txt
#   inflating: aclImdb/test/neg/1312_1.txt
#   inflating: aclImdb/test/pos/10187_10.txt
#   inflating: aclImdb/test/pos/11612_10.txt
#   inflating: aclImdb/test/pos/11605_7.txt
#   inflating: aclImdb/test/pos/11611_7.txt
#   inflating: aclImdb/test/neg/2659_1.txt
#   inflating: aclImdb/test/neg/1298_1.txt
#   inflating: aclImdb/test/pos/11607_7.txt
#   inflating: aclImdb/test/neg/1299_1.txt
#   inflating: aclImdb/test/neg/2668_4.txt
#   inflating: aclImdb/test/neg/2652_3.txt
#   inflating: aclImdb/test/pos/11609_10.txt
#   inflating: aclImdb/test/neg/12_4.txt
#   inflating: aclImdb/test/pos/10185_10.txt
#   inflating: aclImdb/test/pos/11602_8.txt
#   inflating: aclImdb/test/neg/2651_2.txt
#   inflating: aclImdb/test/pos/11603_10.txt
#   inflating: aclImdb/test/pos/1018_7.txt
#   inflating: aclImdb/test/pos/10199_10.txt
#   inflating: aclImdb/test/neg/1304_3.txt
#   inflating: aclImdb/test/pos/10183_9.txt
#   inflating: aclImdb/test/pos/10180_8.txt
#   inflating: aclImdb/test/pos/11604_8.txt
#   inflating: aclImdb/test/neg/264_1.txt
#   inflating: aclImdb/test/pos/10188_10.txt
#   inflating: aclImdb/test/neg/2654_2.txt
#   inflating: aclImdb/test/neg/1300_1.txt
#   inflating: aclImdb/test/pos/10181_10.txt
#   inflating: aclImdb/test/pos/11606_8.txt
#   inflating: aclImdb/test/neg/129_1.txt
#   inflating: aclImdb/test/neg/2658_3.txt
#   inflating: aclImdb/test/pos/11608_9.txt
#   inflating: aclImdb/test/pos/10189_10.txt
#   inflating: aclImdb/test/pos/1160_10.txt
#   inflating: aclImdb/test/neg/2647_2.txt
#   inflating: aclImdb/test/pos/1017_7.txt
#   inflating: aclImdb/test/neg/1294_4.txt
#   inflating: aclImdb/test/neg/2650_2.txt
#   inflating: aclImdb/test/neg/2657_2.txt
#   inflating: aclImdb/test/pos/10174_9.txt
#   inflating: aclImdb/test/pos/11610_10.txt
#   inflating: aclImdb/test/neg/2656_1.txt
#   inflating: aclImdb/test/neg/1297_2.txt
#   inflating: aclImdb/test/pos/10179_10.txt
#   inflating: aclImdb/test/neg/2649_2.txt
#   inflating: aclImdb/test/pos/11591_10.txt
#   inflating: aclImdb/test/pos/11601_9.txt
#   inflating: aclImdb/test/pos/10184_9.txt
#   inflating: aclImdb/test/neg/2653_4.txt
#   inflating: aclImdb/test/neg/2655_3.txt
#   inflating: aclImdb/test/neg/1295_1.txt
#   inflating: aclImdb/test/pos/11596_10.txt
#   inflating: aclImdb/test/pos/10169_8.txt
#   inflating: aclImdb/test/neg/1301_1.txt
#   inflating: aclImdb/test/pos/11600_10.txt
#   inflating: aclImdb/test/neg/2646_3.txt
#   inflating: aclImdb/test/pos/10173_8.txt
#   inflating: aclImdb/test/pos/10170_8.txt
#   inflating: aclImdb/test/neg/1292_3.txt
#   inflating: aclImdb/test/pos/11597_9.txt
#   inflating: aclImdb/test/neg/1296_1.txt
#   inflating: aclImdb/test/pos/11594_9.txt
#   inflating: aclImdb/test/neg/2642_4.txt
#   inflating: aclImdb/test/pos/11595_9.txt
#   inflating: aclImdb/test/pos/10171_8.txt
#   inflating: aclImdb/test/neg/2641_3.txt
#   inflating: aclImdb/test/neg/1285_1.txt
#   inflating: aclImdb/test/neg/128_4.txt
#   inflating: aclImdb/test/pos/11599_7.txt
#   inflating: aclImdb/test/neg/2644_1.txt
#   inflating: aclImdb/test/pos/10175_7.txt
#   inflating: aclImdb/test/neg/1284_1.txt
#   inflating: aclImdb/test/pos/115_9.txt
#   inflating: aclImdb/test/neg/1287_1.txt
#   inflating: aclImdb/test/neg/263_1.txt
#   inflating: aclImdb/test/pos/10178_10.txt
#   inflating: aclImdb/test/pos/10176_9.txt
#   inflating: aclImdb/test/neg/1293_1.txt
#   inflating: aclImdb/test/neg/2640_3.txt
#   inflating: aclImdb/test/pos/1016_7.txt
#   inflating: aclImdb/test/neg/1289_1.txt
#   inflating: aclImdb/test/pos/10177_10.txt
#   inflating: aclImdb/test/pos/11598_10.txt
#   inflating: aclImdb/test/neg/2643_3.txt
#   inflating: aclImdb/test/pos/10172_9.txt
#   inflating: aclImdb/test/neg/2645_4.txt
#   inflating: aclImdb/test/pos/11593_10.txt
#   inflating: aclImdb/test/pos/1159_8.txt
#   inflating: aclImdb/test/neg/2639_4.txt
#   inflating: aclImdb/test/pos/10159_7.txt
#   inflating: aclImdb/test/neg/1291_1.txt
#   inflating: aclImdb/test/neg/1288_1.txt
#   inflating: aclImdb/test/pos/10158_9.txt
#   inflating: aclImdb/test/pos/11590_10.txt
#   inflating: aclImdb/test/neg/2636_1.txt
#   inflating: aclImdb/test/neg/1290_2.txt
#   inflating: aclImdb/test/pos/11592_10.txt
#   inflating: aclImdb/test/neg/2638_1.txt
#   inflating: aclImdb/test/pos/11584_10.txt
#   inflating: aclImdb/test/neg/2637_1.txt
#   inflating: aclImdb/test/pos/1158_7.txt
#   inflating: aclImdb/test/pos/11582_7.txt
#   inflating: aclImdb/test/pos/10165_9.txt
#   inflating: aclImdb/test/neg/1286_1.txt
#   inflating: aclImdb/test/pos/10168_9.txt
#   inflating: aclImdb/test/pos/11586_9.txt
#   inflating: aclImdb/test/neg/1302_1.txt
#   inflating: aclImdb/test/neg/1283_1.txt
#   inflating: aclImdb/test/pos/11583_10.txt
#   inflating: aclImdb/test/neg/2626_4.txt
#   inflating: aclImdb/test/neg/1274_2.txt
#   inflating: aclImdb/test/neg/2635_1.txt
#   inflating: aclImdb/test/neg/2633_1.txt
#   inflating: aclImdb/test/pos/10162_10.txt
#   inflating: aclImdb/test/neg/1276_3.txt
#   inflating: aclImdb/test/neg/2630_2.txt
#   inflating: aclImdb/test/pos/10167_9.txt
#   inflating: aclImdb/test/pos/10160_7.txt
#   inflating: aclImdb/test/neg/1281_2.txt
#   inflating: aclImdb/test/pos/10163_7.txt
#   inflating: aclImdb/test/pos/11581_7.txt
#   inflating: aclImdb/test/neg/1279_3.txt
#   inflating: aclImdb/test/pos/10166_8.txt
#   inflating: aclImdb/test/neg/2627_4.txt
#   inflating: aclImdb/test/neg/1278_1.txt
#   inflating: aclImdb/test/pos/11580_7.txt
#   inflating: aclImdb/test/neg/2632_1.txt
#   inflating: aclImdb/test/pos/11589_9.txt
#   inflating: aclImdb/test/neg/262_1.txt
#   inflating: aclImdb/test/pos/1015_8.txt
#   inflating: aclImdb/test/pos/11587_8.txt
#   inflating: aclImdb/test/neg/2629_4.txt
#   inflating: aclImdb/test/pos/11585_7.txt
#   inflating: aclImdb/test/neg/1275_3.txt
#   inflating: aclImdb/test/neg/2631_4.txt
#   inflating: aclImdb/test/neg/1282_3.txt
#   inflating: aclImdb/test/pos/11588_7.txt
#   inflating: aclImdb/test/pos/10161_7.txt
#   inflating: aclImdb/test/pos/10157_8.txt
#   inflating: aclImdb/test/neg/1273_3.txt
#   inflating: aclImdb/test/neg/127_3.txt
#   inflating: aclImdb/test/pos/10153_10.txt
#   inflating: aclImdb/test/neg/1280_3.txt
#   inflating: aclImdb/test/pos/11579_10.txt
#   inflating: aclImdb/test/pos/11576_10.txt
#   inflating: aclImdb/test/pos/10151_8.txt
#   inflating: aclImdb/test/neg/2628_1.txt
#   inflating: aclImdb/test/pos/1157_9.txt
#   inflating: aclImdb/test/neg/2616_1.txt
#   inflating: aclImdb/test/neg/2634_1.txt
#   inflating: aclImdb/test/pos/10148_10.txt
#   inflating: aclImdb/test/pos/11578_10.txt
#   inflating: aclImdb/test/pos/10164_9.txt
#   inflating: aclImdb/test/neg/1267_3.txt
#   inflating: aclImdb/test/neg/2625_1.txt
#   inflating: aclImdb/test/neg/1271_2.txt
#   inflating: aclImdb/test/pos/1014_8.txt
#   inflating: aclImdb/test/neg/1270_4.txt
#   inflating: aclImdb/test/pos/10149_9.txt
#   inflating: aclImdb/test/pos/11574_10.txt
#   inflating: aclImdb/test/pos/11573_10.txt
#   inflating: aclImdb/test/neg/2620_3.txt
#   inflating: aclImdb/test/neg/2617_2.txt
#   inflating: aclImdb/test/pos/11572_8.txt
#   inflating: aclImdb/test/neg/1269_1.txt
#   inflating: aclImdb/test/neg/1265_2.txt
#   inflating: aclImdb/test/neg/2622_2.txt
#   inflating: aclImdb/test/neg/1277_2.txt
#   inflating: aclImdb/test/neg/1272_4.txt
#   inflating: aclImdb/test/neg/1268_2.txt
#   inflating: aclImdb/test/neg/261_3.txt
#   inflating: aclImdb/test/neg/2624_1.txt
#   inflating: aclImdb/test/neg/2619_2.txt
#   inflating: aclImdb/test/pos/11575_10.txt
#   inflating: aclImdb/test/neg/1262_1.txt
#   inflating: aclImdb/test/neg/1263_1.txt
#   inflating: aclImdb/test/neg/2618_1.txt
#   inflating: aclImdb/test/neg/2615_1.txt
#   inflating: aclImdb/test/neg/2621_2.txt
#   inflating: aclImdb/test/pos/11577_10.txt
#   inflating: aclImdb/test/pos/11571_9.txt
#   inflating: aclImdb/test/neg/126_4.txt
#   inflating: aclImdb/test/neg/2623_1.txt
#   inflating: aclImdb/test/pos/1156_9.txt
#   inflating: aclImdb/test/pos/11567_9.txt
#   inflating: aclImdb/test/pos/11569_7.txt
#   inflating: aclImdb/test/neg/2613_1.txt
#   inflating: aclImdb/test/pos/11570_10.txt
#   inflating: aclImdb/test/neg/1264_1.txt
#   inflating: aclImdb/test/pos/11568_10.txt
#   inflating: aclImdb/test/pos/11564_7.txt
#   inflating: aclImdb/test/neg/125_3.txt
#   inflating: aclImdb/test/neg/1260_3.txt
#   inflating: aclImdb/test/neg/2611_1.txt
#   inflating: aclImdb/test/neg/2614_3.txt
#   inflating: aclImdb/test/neg/1256_4.txt
#   inflating: aclImdb/test/neg/1261_1.txt
#   inflating: aclImdb/test/neg/2609_2.txt
#   inflating: aclImdb/test/neg/1266_4.txt
#   inflating: aclImdb/test/pos/11558_9.txt
#   inflating: aclImdb/test/neg/1252_4.txt
#   inflating: aclImdb/test/neg/2606_4.txt
#   inflating: aclImdb/test/neg/260_1.txt
#   inflating: aclImdb/test/pos/11562_8.txt
#   inflating: aclImdb/test/pos/11560_8.txt
#   inflating: aclImdb/test/neg/1258_3.txt
#   inflating: aclImdb/test/pos/11563_8.txt
#   inflating: aclImdb/test/neg/1255_4.txt
#   inflating: aclImdb/test/neg/2605_4.txt
#   inflating: aclImdb/test/neg/2607_1.txt
#   inflating: aclImdb/test/neg/2608_3.txt
#   inflating: aclImdb/test/pos/11566_8.txt
#   inflating: aclImdb/test/neg/2610_1.txt
#   inflating: aclImdb/test/neg/1250_2.txt
#   inflating: aclImdb/test/neg/1259_1.txt
#   inflating: aclImdb/test/neg/2604_1.txt
#   inflating: aclImdb/test/neg/2603_1.txt
#   inflating: aclImdb/test/pos/11559_9.txt
#   inflating: aclImdb/test/pos/11557_7.txt
#   inflating: aclImdb/test/neg/2596_1.txt
#   inflating: aclImdb/test/neg/2595_2.txt
#   inflating: aclImdb/test/pos/11556_9.txt
#   inflating: aclImdb/test/pos/1155_7.txt
#   inflating: aclImdb/test/pos/11553_7.txt
#   inflating: aclImdb/test/neg/124_2.txt
#   inflating: aclImdb/test/neg/1257_1.txt
#   inflating: aclImdb/test/pos/11561_8.txt
#   inflating: aclImdb/test/neg/1254_2.txt
#   inflating: aclImdb/test/pos/11565_7.txt
#   inflating: aclImdb/test/neg/1249_1.txt
#   inflating: aclImdb/test/neg/2597_1.txt
#   inflating: aclImdb/test/neg/1251_4.txt
#   inflating: aclImdb/test/neg/2599_1.txt
#   inflating: aclImdb/test/pos/11551_7.txt
#   inflating: aclImdb/test/neg/12497_4.txt
#   inflating: aclImdb/test/neg/12496_3.txt
#   inflating: aclImdb/test/neg/25_3.txt
#   inflating: aclImdb/test/neg/2598_1.txt
#   inflating: aclImdb/test/neg/2602_1.txt
#   inflating: aclImdb/test/pos/11549_10.txt
#   inflating: aclImdb/test/neg/12495_3.txt
#   inflating: aclImdb/test/neg/12494_2.txt
#   inflating: aclImdb/test/neg/2612_1.txt
#   inflating: aclImdb/test/neg/12492_4.txt
#   inflating: aclImdb/test/pos/1154_10.txt
#   inflating: aclImdb/test/pos/11552_10.txt
#   inflating: aclImdb/test/neg/259_2.txt
#   inflating: aclImdb/test/pos/11554_10.txt
#   inflating: aclImdb/test/neg/12493_4.txt
#   inflating: aclImdb/test/neg/12499_1.txt
#   inflating: aclImdb/test/pos/11555_7.txt
#   inflating: aclImdb/test/neg/2601_1.txt
#   inflating: aclImdb/test/neg/12498_1.txt
#   inflating: aclImdb/test/neg/2593_1.txt
#   inflating: aclImdb/test/neg/12491_4.txt
#   inflating: aclImdb/test/neg/2594_3.txt
#   inflating: aclImdb/test/pos/11546_10.txt
#   inflating: aclImdb/test/neg/1253_1.txt
#   inflating: aclImdb/test/neg/12490_4.txt
#   inflating: aclImdb/test/pos/11548_10.txt
#   inflating: aclImdb/test/neg/1248_3.txt
#   inflating: aclImdb/test/pos/1153_8.txt
#   inflating: aclImdb/test/pos/11540_10.txt
#   inflating: aclImdb/test/neg/12489_3.txt
#   inflating: aclImdb/test/pos/11550_10.txt
#   inflating: aclImdb/test/pos/11547_9.txt
#   inflating: aclImdb/test/neg/2588_3.txt
#   inflating: aclImdb/test/neg/2590_1.txt
#   inflating: aclImdb/test/pos/11544_10.txt
#   inflating: aclImdb/test/pos/11539_10.txt
#   inflating: aclImdb/test/neg/2600_1.txt
#   inflating: aclImdb/test/pos/11537_7.txt
#   inflating: aclImdb/test/neg/12484_2.txt
#   inflating: aclImdb/test/neg/2589_2.txt
#   inflating: aclImdb/test/neg/2583_1.txt
#   inflating: aclImdb/test/neg/12482_2.txt
#   inflating: aclImdb/test/pos/11542_10.txt
#   inflating: aclImdb/test/pos/11543_10.txt
#   inflating: aclImdb/test/pos/11541_9.txt
#   inflating: aclImdb/test/neg/258_1.txt
#   inflating: aclImdb/test/pos/11545_10.txt
#   inflating: aclImdb/test/pos/11529_8.txt
#   inflating: aclImdb/test/neg/2587_3.txt
#   inflating: aclImdb/test/neg/2592_1.txt
#   inflating: aclImdb/test/neg/12485_4.txt
#   inflating: aclImdb/test/neg/12481_1.txt
#   inflating: aclImdb/test/neg/2585_1.txt
#   inflating: aclImdb/test/pos/11538_8.txt
#   inflating: aclImdb/test/neg/2591_1.txt
#   inflating: aclImdb/test/pos/11536_7.txt
#   inflating: aclImdb/test/neg/12488_3.txt
#   inflating: aclImdb/test/pos/1152_8.txt
#   inflating: aclImdb/test/pos/11535_10.txt
#   inflating: aclImdb/test/pos/11530_8.txt
#   inflating: aclImdb/test/pos/11526_8.txt
#   inflating: aclImdb/test/neg/2586_1.txt
#   inflating: aclImdb/test/pos/11518_10.txt
#   inflating: aclImdb/test/pos/11522_8.txt
#   inflating: aclImdb/test/pos/11520_7.txt
#   inflating: aclImdb/test/pos/11519_7.txt
#   inflating: aclImdb/test/pos/1151_9.txt
#   inflating: aclImdb/test/pos/11516_7.txt
#   inflating: aclImdb/test/pos/11524_10.txt
#   inflating: aclImdb/test/pos/11533_9.txt
#   inflating: aclImdb/test/pos/11532_8.txt
#   inflating: aclImdb/test/pos/11531_8.txt
#   inflating: aclImdb/test/pos/11527_10.txt
#   inflating: aclImdb/test/pos/11534_7.txt
#   inflating: aclImdb/test/pos/11528_9.txt
#   inflating: aclImdb/test/pos/11525_7.txt
#   inflating: aclImdb/test/pos/11523_7.txt
#   inflating: aclImdb/test/pos/11517_8.txt
#   inflating: aclImdb/test/pos/11514_8.txt
#   inflating: aclImdb/test/pos/11515_7.txt
#   inflating: aclImdb/test/pos/1150_9.txt
#   inflating: aclImdb/test/pos/11521_10.txt
#   inflating: aclImdb/test/pos/11507_10.txt
#   inflating: aclImdb/test/pos/11511_10.txt
#   inflating: aclImdb/test/pos/11509_10.txt
#   inflating: aclImdb/test/pos/11510_9.txt
#   inflating: aclImdb/test/pos/11506_10.txt
#   inflating: aclImdb/test/pos/11513_10.txt
#   inflating: aclImdb/test/pos/11505_10.txt
#   inflating: aclImdb/test/pos/11512_8.txt
#   inflating: aclImdb/test/pos/11508_9.txt
#   inflating: aclImdb/test/pos/11504_10.txt
#   inflating: aclImdb/test/pos/11503_8.txt
#   inflating: aclImdb/test/pos/11502_10.txt

# %%
# warning: this may take quite a while to load!
# you may get a time-out error, if so, just re-run the cell
# or you need to move the data to "My Drive" so it's a shorter
# file path

import os

imdb_dir = '/content/aclImdb/test'

labels = []
texts = []
count = 0
for label_type in ['neg/', 'pos/']:
    dir_name = os.path.join(imdb_dir, label_type)
    for fname in os.listdir(dir_name):
        if fname[-4:] == '.txt':
            count = count + 1
            print(count)
            f = open(os.path.join(dir_name, fname))
            texts.append(f.read())
            f.close()
            if label_type == 'neg/':
                labels.append(0)
            else:
                labels.append(1)
# Out:
# Streaming output truncated to the last 5000 lines.
# 4679
# 4680
# 4681
# 4682
# 4683
# 4684
# 4685
# 4686
# 4687
# 4688
# 4689
# 4690
# 4691
# 4692
# 4693
# 4694
# 4695
# 4696
# 4697
# 4698
# 4699
# 4700
# 4701
# 4702
# 4703
# 4704
# 4705
# 4706
# 4707
# 4708
# 4709
# 4710
# 4711
# 4712
# 4713
# 4714
# 4715
# 4716
# 4717
# 4718
# 4719
# 4720
# 4721
# 4722
# 4723
# 4724
# 4725
# 4726
# 4727
# 4728
# 4729
# 4730
# 4731
# 4732
# 4733
# 4734
# 4735
# 4736
# 4737
# 4738
# 4739
# 4740
# 4741
# 4742
# 4743
# 4744
# 4745
# 4746
# 4747
# 4748
# 4749
# 4750
# 4751
# 4752
# 4753
# 4754
# 4755
# 4756
# 4757
# 4758
# 4759
# 4760
# 4761
# 4762
# 4763
# 4764
# 4765
# 4766
# 4767
# 4768
# 4769
# 4770
# 4771
# 4772
# 4773
# 4774
# 4775
# 4776
# 4777
# 4778
# 4779
# 4780
# 4781
# 4782
# 4783
# 4784
# 4785
# 4786
# 4787
# 4788
# 4789
# 4790
# 4791
# 4792
# 4793
# 4794
# 4795
# 4796
# 4797
# 4798
# 4799
# 4800
# 4801
# 4802
# 4803
# 4804
# 4805
# 4806
# 4807
# 4808
# 4809
# 4810
# 4811
# 4812
# 4813
# 4814
# 4815
# 4816
# 4817
# 4818
# 4819
# 4820
# 4821
# 4822
# 4823
# 4824
# 4825
# 4826
# 4827
# 4828
# 4829
# 4830
# 4831
# 4832
# 4833
# 4834
# 4835
# 4836
# 4837
# 4838
# 4839
# 4840
# 4841
# 4842
# 4843
# 4844
# 4845
# 4846
# 4847
# 4848
# 4849
# 4850
# 4851
# 4852
# 4853
# 4854
# 4855
# 4856
# 4857
# 4858
# 4859
# 4860
# 4861
# 4862
# 4863
# 4864
# 4865
# 4866
# 4867
# 4868
# 4869
# 4870
# 4871
# 4872
# 4873
# 4874
# 4875
# 4876
# 4877
# 4878
# 4879
# 4880
# 4881
# 4882
# 4883
# 4884
# 4885
# 4886
# 4887
# 4888
# 4889
# 4890
# 4891
# 4892
# 4893
# 4894
# 4895
# 4896
# 4897
# 4898
# 4899
# 4900
# 4901
# 4902
# 4903
# 4904
# 4905
# 4906
# 4907
# 4908
# 4909
# 4910
# 4911
# 4912
# 4913
# 4914
# 4915
# 4916
# 4917
# 4918
# 4919
# 4920
# 4921
# 4922
# 4923
# 4924
# 4925
# 4926
# 4927
# 4928
# 4929
# 4930
# 4931
# 4932
# 4933
# 4934
# 4935
# 4936
# 4937
# 4938
# 4939
# 4940
# 4941
# 4942
# 4943
# 4944
# 4945
# 4946
# 4947
# 4948
# 4949
# 4950
# 4951
# 4952
# 4953
# 4954
# 4955
# 4956
# 4957
# 4958
# 4959
# 4960
# 4961
# 4962
# 4963
# 4964
# 4965
# 4966
# 4967
# 4968
# 4969
# 4970
# 4971
# 4972
# 4973
# 4974
# 4975
# 4976
# 4977
# 4978
# 4979
# 4980
# 4981
# 4982
# 4983
# 4984
# 4985
# 4986
# 4987
# 4988
# 4989
# 4990
# 4991
# 4992
# 4993
# 4994
# 4995
# 4996
# 4997
# 4998
# 4999
# 5000
# 5001
# 5002
# 5003
# 5004
# 5005
# 5006
# 5007
# 5008
# 5009
# 5010
# 5011
# 5012
# 5013
# 5014
# 5015
# 5016
# 5017
# 5018
# 5019
# 5020
# 5021
# 5022
# 5023
# 5024
# 5025
# 5026
# 5027
# 5028
# 5029
# 5030
# 5031
# 5032
# 5033
# 5034
# 5035
# 5036
# 5037
# 5038
# 5039
# 5040
# 5041
# 5042
# 5043
# 5044
# 5045
# 5046
# 5047
# 5048
# 5049
# 5050
# 5051
# 5052
# 5053
# 5054
# 5055
# 5056
# 5057
# 5058
# 5059
# 5060
# 5061
# 5062
# 5063
# 5064
# 5065
# 5066
# 5067
# 5068
# 5069
# 5070
# 5071
# 5072
# 5073
# 5074
# 5075
# 5076
# 5077
# 5078
# 5079
# 5080
# 5081
# 5082
# 5083
# 5084
# 5085
# 5086
# 5087
# 5088
# 5089
# 5090
# 5091
# 5092
# 5093
# 5094
# 5095
# 5096
# 5097
# 5098
# 5099
# 5100
# 5101
# 5102
# 5103
# 5104
# 5105
# 5106
# 5107
# 5108
# 5109
# 5110
# 5111
# 5112
# 5113
# 5114
# 5115
# 5116
# 5117
# 5118
# 5119
# 5120
# 5121
# 5122
# 5123
# 5124
# 5125
# 5126
# 5127
# 5128
# 5129
# 5130
# 5131
# 5132
# 5133
# 5134
# 5135
# 5136
# 5137
# 5138
# 5139
# 5140
# 5141
# 5142
# 5143
# 5144
# 5145
# 5146
# 5147
# 5148
# 5149
# 5150
# 5151
# 5152
# 5153
# 5154
# 5155
# 5156
# 5157
# 5158
# 5159
# 5160
# 5161
# 5162
# 5163
# 5164
# 5165
# 5166
# 5167
# 5168
# 5169
# 5170
# 5171
# 5172
# 5173
# 5174
# 5175
# 5176
# 5177
# 5178
# 5179
# 5180
# 5181
# 5182
# 5183
# 5184
# 5185
# 5186
# 5187
# 5188
# 5189
# 5190
# 5191
# 5192
# 5193
# 5194
# 5195
# 5196
# 5197
# 5198
# 5199
# 5200
# 5201
# 5202
# 5203
# 5204
# 5205
# 5206
# 5207
# 5208
# 5209
# 5210
# 5211
# 5212
# 5213
# 5214
# 5215
# 5216
# 5217
# 5218
# 5219
# 5220
# 5221
# 5222
# 5223
# 5224
# 5225
# 5226
# 5227
# 5228
# 5229
# 5230
# 5231
# 5232
# 5233
# 5234
# 5235
# 5236
# 5237
# 5238
# 5239
# 5240
# 5241
# 5242
# 5243
# 5244
# 5245
# 5246
# 5247
# 5248
# 5249
# 5250
# 5251
# 5252
# 5253
# 5254
# 5255
# 5256
# 5257
# 5258
# 5259
# 5260
# 5261
# 5262
# 5263
# 5264
# 5265
# 5266
# 5267
# 5268
# 5269
# 5270
# 5271
# 5272
# 5273
# 5274
# 5275
# 5276
# 5277
# 5278
# 5279
# 5280
# 5281
# 5282
# 5283
# 5284
# 5285
# 5286
# 5287
# 5288
# 5289
# 5290
# 5291
# 5292
# 5293
# 5294
# 5295
# 5296
# 5297
# 5298
# 5299
# 5300
# 5301
# 5302
# 5303
# 5304
# 5305
# 5306
# 5307
# 5308
# 5309
# 5310
# 5311
# 5312
# 5313
# 5314
# 5315
# 5316
# 5317
# 5318
# 5319
# 5320
# 5321
# 5322
# 5323
# 5324
# 5325
# 5326
# 5327
# 5328
# 5329
# 5330
# 5331
# 5332
# 5333
# 5334
# 5335
# 5336
# 5337
# 5338
# 5339
# 5340
# 5341
# 5342
# 5343
# 5344
# 5345
# 5346
# 5347
# 5348
# 5349
# 5350
# 5351
# 5352
# 5353
# 5354
# 5355
# 5356
# 5357
# 5358
# 5359
# 5360
# 5361
# 5362
# 5363
# 5364
# 5365
# 5366
# 5367
# 5368
# 5369
# 5370
# 5371
# 5372
# 5373
# 5374
# 5375
# 5376
# 5377
# 5378
# 5379
# 5380
# 5381
# 5382
# 5383
# 5384
# 5385
# 5386
# 5387
# 5388
# 5389
# 5390
# 5391
# 5392
# 5393
# 5394
# 5395
# 5396
# 5397
# 5398
# 5399
# 5400
# 5401
# 5402
# 5403
# 5404
# 5405
# 5406
# 5407
# 5408
# 5409
# 5410
# 5411
# 5412
# 5413
# 5414
# 5415
# 5416
# 5417
# 5418
# 5419
# 5420
# 5421
# 5422
# 5423
# 5424
# 5425
# 5426
# 5427
# 5428
# 5429
# 5430
# 5431
# 5432
# 5433
# 5434
# 5435
# 5436
# 5437
# 5438
# 5439
# 5440
# 5441
# 5442
# 5443
# 5444
# 5445
# 5446
# 5447
# 5448
# 5449
# 5450
# 5451
# 5452
# 5453
# 5454
# 5455
# 5456
# 5457
# 5458
# 5459
# 5460
# 5461
# 5462
# 5463
# 5464
# 5465
# 5466
# 5467
# 5468
# 5469
# 5470
# 5471
# 5472
# 5473
# 5474
# 5475
# 5476
# 5477
# 5478
# 5479
# 5480
# 5481
# 5482
# 5483
# 5484
# 5485
# 5486
# 5487
# 5488
# 5489
# 5490
# 5491
# 5492
# 5493
# 5494
# 5495
# 5496
# 5497
# 5498
# 5499
# 5500
# 5501
# 5502
# 5503
# 5504
# 5505
# 5506
# 5507
# 5508
# 5509
# 5510
# 5511
# 5512
# 5513
# 5514
# 5515
# 5516
# 5517
# 5518
# 5519
# 5520
# 5521
# 5522
# 5523
# 5524
# 5525
# 5526
# 5527
# 5528
# 5529
# 5530
# 5531
# 5532
# 5533
# 5534
# 5535
# 5536
# 5537
# 5538
# 5539
# 5540
# 5541
# 5542
# 5543
# 5544
# 5545
# 5546
# 5547
# 5548
# 5549
# 5550
# 5551
# 5552
# 5553
# 5554
# 5555
# 5556
# 5557
# 5558
# 5559
# 5560
# 5561
# 5562
# 5563
# 5564
# 5565
# 5566
# 5567
# 5568
# 5569
# 5570
# 5571
# 5572
# 5573
# 5574
# 5575
# 5576
# 5577
# 5578
# 5579
# 5580
# 5581
# 5582
# 5583
# 5584
# 5585
# 5586
# 5587
# 5588
# 5589
# 5590
# 5591
# 5592
# 5593
# 5594
# 5595
# 5596
# 5597
# 5598
# 5599
# 5600
# 5601
# 5602
# 5603
# 5604
# 5605
# 5606
# 5607
# 5608
# 5609
# 5610
# 5611
# 5612
# 5613
# 5614
# 5615
# 5616
# 5617
# 5618
# 5619
# 5620
# 5621
# 5622
# 5623
# 5624
# 5625
# 5626
# 5627
# 5628
# 5629
# 5630
# 5631
# 5632
# 5633
# 5634
# 5635
# 5636
# 5637
# 5638
# 5639
# 5640
# 5641
# 5642
# 5643
# 5644
# 5645
# 5646
# 5647
# 5648
# 5649
# 5650
# 5651
# 5652
# 5653
# 5654
# 5655
# 5656
# 5657
# 5658
# 5659
# 5660
# 5661
# 5662
# 5663
# 5664
# 5665
# 5666
# 5667
# 5668
# 5669
# 5670
# 5671
# 5672
# 5673
# 5674
# 5675
# 5676
# 5677
# 5678
# 5679
# 5680
# 5681
# 5682
# 5683
# 5684
# 5685
# 5686
# 5687
# 5688
# 5689
# 5690
# 5691
# 5692
# 5693
# 5694
# 5695
# 5696
# 5697
# 5698
# 5699
# 5700
# 5701
# 5702
# 5703
# 5704
# 5705
# 5706
# 5707
# 5708
# 5709
# 5710
# 5711
# 5712
# 5713
# 5714
# 5715
# 5716
# 5717
# 5718
# 5719
# 5720
# 5721
# 5722
# 5723
# 5724
# 5725
# 5726
# 5727
# 5728
# 5729
# 5730
# 5731
# 5732
# 5733
# 5734
# 5735
# 5736
# 5737
# 5738
# 5739
# 5740
# 5741
# 5742
# 5743
# 5744
# 5745
# 5746
# 5747
# 5748
# 5749
# 5750
# 5751
# 5752
# 5753
# 5754
# 5755
# 5756
# 5757
# 5758
# 5759
# 5760
# 5761
# 5762
# 5763
# 5764
# 5765
# 5766
# 5767
# 5768
# 5769
# 5770
# 5771
# 5772
# 5773
# 5774
# 5775
# 5776
# 5777
# 5778
# 5779
# 5780
# 5781
# 5782
# 5783
# 5784
# 5785
# 5786
# 5787
# 5788
# 5789
# 5790
# 5791
# 5792
# 5793
# 5794
# 5795
# 5796
# 5797
# 5798
# 5799
# 5800
# 5801
# 5802
# 5803
# 5804
# 5805
# 5806
# 5807
# 5808
# 5809
# 5810
# 5811
# 5812
# 5813
# 5814
# 5815
# 5816
# 5817
# 5818
# 5819
# 5820
# 5821
# 5822
# 5823
# 5824
# 5825
# 5826
# 5827
# 5828
# 5829
# 5830
# 5831
# 5832
# 5833
# 5834
# 5835
# 5836
# 5837
# 5838
# 5839
# 5840
# 5841
# 5842
# 5843
# 5844
# 5845
# 5846
# 5847
# 5848
# 5849
# 5850
# 5851
# 5852
# 5853
# 5854
# 5855
# 5856
# 5857
# 5858
# 5859
# 5860
# 5861
# 5862
# 5863
# 5864
# 5865
# 5866
# 5867
# 5868
# 5869
# 5870
# 5871
# 5872
# 5873
# 5874
# 5875
# 5876
# 5877
# 5878
# 5879
# 5880
# 5881
# 5882
# 5883
# 5884
# 5885
# 5886
# 5887
# 5888
# 5889
# 5890
# 5891
# 5892
# 5893
# 5894
# 5895
# 5896
# 5897
# 5898
# 5899
# 5900
# 5901
# 5902
# 5903
# 5904
# 5905
# 5906
# 5907
# 5908
# 5909
# 5910
# 5911
# 5912
# 5913
# 5914
# 5915
# 5916
# 5917
# 5918
# 5919
# 5920
# 5921
# 5922
# 5923
# 5924
# 5925
# 5926
# 5927
# 5928
# 5929
# 5930
# 5931
# 5932
# 5933
# 5934
# 5935
# 5936
# 5937
# 5938
# 5939
# 5940
# 5941
# 5942
# 5943
# 5944
# 5945
# 5946
# 5947
# 5948
# 5949
# 5950
# 5951
# 5952
# 5953
# 5954
# 5955
# 5956
# 5957
# 5958
# 5959
# 5960
# 5961
# 5962
# 5963
# 5964
# 5965
# 5966
# 5967
# 5968
# 5969
# 5970
# 5971
# 5972
# 5973
# 5974
# 5975
# 5976
# 5977
# 5978
# 5979
# 5980
# 5981
# 5982
# 5983
# 5984
# 5985
# 5986
# 5987
# 5988
# 5989
# 5990
# 5991
# 5992
# 5993
# 5994
# 5995
# 5996
# 5997
# 5998
# 5999
# 6000
# 6001
# 6002
# 6003
# 6004
# 6005
# 6006
# 6007
# 6008
# 6009
# 6010
# 6011
# 6012
# 6013
# 6014
# 6015
# 6016
# 6017
# 6018
# 6019
# 6020
# 6021
# 6022
# 6023
# 6024
# 6025
# 6026
# 6027
# 6028
# 6029
# 6030
# 6031
# 6032
# 6033
# 6034
# 6035
# 6036
# 6037
# 6038
# 6039
# 6040
# 6041
# 6042
# 6043
# 6044
# 6045
# 6046
# 6047
# 6048
# 6049
# 6050
# 6051
# 6052
# 6053
# 6054
# 6055
# 6056
# 6057
# 6058
# 6059
# 6060
# 6061
# 6062
# 6063
# 6064
# 6065
# 6066
# 6067
# 6068
# 6069
# 6070
# 6071
# 6072
# 6073
# 6074
# 6075
# 6076
# 6077
# 6078
# 6079
# 6080
# 6081
# 6082
# 6083
# 6084
# 6085
# 6086
# 6087
# 6088
# 6089
# 6090
# 6091
# 6092
# 6093
# 6094
# 6095
# 6096
# 6097
# 6098
# 6099
# 6100
# 6101
# 6102
# 6103
# 6104
# 6105
# 6106
# 6107
# 6108
# 6109
# 6110
# 6111
# 6112
# 6113
# 6114
# 6115
# 6116
# 6117
# 6118
# 6119
# 6120
# 6121
# 6122
# 6123
# 6124
# 6125
# 6126
# 6127
# 6128
# 6129
# 6130
# 6131
# 6132
# 6133
# 6134
# 6135
# 6136
# 6137
# 6138
# 6139
# 6140
# 6141
# 6142
# 6143
# 6144
# 6145
# 6146
# 6147
# 6148
# 6149
# 6150
# 6151
# 6152
# 6153
# 6154
# 6155
# 6156
# 6157
# 6158
# 6159
# 6160
# 6161
# 6162
# 6163
# 6164
# 6165
# 6166
# 6167
# 6168
# 6169
# 6170
# 6171
# 6172
# 6173
# 6174
# 6175
# 6176
# 6177
# 6178
# 6179
# 6180
# 6181
# 6182
# 6183
# 6184
# 6185
# 6186
# 6187
# 6188
# 6189
# 6190
# 6191
# 6192
# 6193
# 6194
# 6195
# 6196
# 6197
# 6198
# 6199
# 6200
# 6201
# 6202
# 6203
# 6204
# 6205
# 6206
# 6207
# 6208
# 6209
# 6210
# 6211
# 6212
# 6213
# 6214
# 6215
# 6216
# 6217
# 6218
# 6219
# 6220
# 6221
# 6222
# 6223
# 6224
# 6225
# 6226
# 6227
# 6228
# 6229
# 6230
# 6231
# 6232
# 6233
# 6234
# 6235
# 6236
# 6237
# 6238
# 6239
# 6240
# 6241
# 6242
# 6243
# 6244
# 6245
# 6246
# 6247
# 6248
# 6249
# 6250
# 6251
# 6252
# 6253
# 6254
# 6255
# 6256
# 6257
# 6258
# 6259
# 6260
# 6261
# 6262
# 6263
# 6264
# 6265
# 6266
# 6267
# 6268
# 6269
# 6270
# 6271
# 6272
# 6273
# 6274
# 6275
# 6276
# 6277
# 6278
# 6279
# 6280
# 6281
# 6282
# 6283
# 6284
# 6285
# 6286
# 6287
# 6288
# 6289
# 6290
# 6291
# 6292
# 6293
# 6294
# 6295
# 6296
# 6297
# 6298
# 6299
# 6300
# 6301
# 6302
# 6303
# 6304
# 6305
# 6306
# 6307
# 6308
# 6309
# 6310
# 6311
# 6312
# 6313
# 6314
# 6315
# 6316
# 6317
# 6318
# 6319
# 6320
# 6321
# 6322
# 6323
# 6324
# 6325
# 6326
# 6327
# 6328
# 6329
# 6330
# 6331
# 6332
# 6333
# 6334
# 6335
# 6336
# 6337
# 6338
# 6339
# 6340
# 6341
# 6342
# 6343
# 6344
# 6345
# 6346
# 6347
# 6348
# 6349
# 6350
# 6351
# 6352
# 6353
# 6354
# 6355
# 6356
# 6357
# 6358
# 6359
# 6360
# 6361
# 6362
# 6363
# 6364
# 6365
# 6366
# 6367
# 6368
# 6369
# 6370
# 6371
# 6372
# 6373
# 6374
# 6375
# 6376
# 6377
# 6378
# 6379
# 6380
# 6381
# 6382
# 6383
# 6384
# 6385
# 6386
# 6387
# 6388
# 6389
# 6390
# 6391
# 6392
# 6393
# 6394
# 6395
# 6396
# 6397
# 6398
# 6399
# 6400
# 6401
# 6402
# 6403
# 6404
# 6405
# 6406
# 6407
# 6408
# 6409
# 6410
# 6411
# 6412
# 6413
# 6414
# 6415
# 6416
# 6417
# 6418
# 6419
# 6420
# 6421
# 6422
# 6423
# 6424
# 6425
# 6426
# 6427
# 6428
# 6429
# 6430
# 6431
# 6432
# 6433
# 6434
# 6435
# 6436
# 6437
# 6438
# 6439
# 6440
# 6441
# 6442
# 6443
# 6444
# 6445
# 6446
# 6447
# 6448
# 6449
# 6450
# 6451
# 6452
# 6453
# 6454
# 6455
# 6456
# 6457
# 6458
# 6459
# 6460
# 6461
# 6462
# 6463
# 6464
# 6465
# 6466
# 6467
# 6468
# 6469
# 6470
# 6471
# 6472
# 6473
# 6474
# 6475
# 6476
# 6477
# 6478
# 6479
# 6480
# 6481
# 6482
# 6483
# 6484
# 6485
# 6486
# 6487
# 6488
# 6489
# 6490
# 6491
# 6492
# 6493
# 6494
# 6495
# 6496
# 6497
# 6498
# 6499
# 6500
# 6501
# 6502
# 6503
# 6504
# 6505
# 6506
# 6507
# 6508
# 6509
# 6510
# 6511
# 6512
# 6513
# 6514
# 6515
# 6516
# 6517
# 6518
# 6519
# 6520
# 6521
# 6522
# 6523
# 6524
# 6525
# 6526
# 6527
# 6528
# 6529
# 6530
# 6531
# 6532
# 6533
# 6534
# 6535
# 6536
# 6537
# 6538
# 6539
# 6540
# 6541
# 6542
# 6543
# 6544
# 6545
# 6546
# 6547
# 6548
# 6549
# 6550
# 6551
# 6552
# 6553
# 6554
# 6555
# 6556
# 6557
# 6558
# 6559
# 6560
# 6561
# 6562
# 6563
# 6564
# 6565
# 6566
# 6567
# 6568
# 6569
# 6570
# 6571
# 6572
# 6573
# 6574
# 6575
# 6576
# 6577
# 6578
# 6579
# 6580
# 6581
# 6582
# 6583
# 6584
# 6585
# 6586
# 6587
# 6588
# 6589
# 6590
# 6591
# 6592
# 6593
# 6594
# 6595
# 6596
# 6597
# 6598
# 6599
# 6600
# 6601
# 6602
# 6603
# 6604
# 6605
# 6606
# 6607
# 6608
# 6609
# 6610
# 6611
# 6612
# 6613
# 6614
# 6615
# 6616
# 6617
# 6618
# 6619
# 6620
# 6621
# 6622
# 6623
# 6624
# 6625
# 6626
# 6627
# 6628
# 6629
# 6630
# 6631
# 6632
# 6633
# 6634
# 6635
# 6636
# 6637
# 6638
# 6639
# 6640
# 6641
# 6642
# 6643
# 6644
# 6645
# 6646
# 6647
# 6648
# 6649
# 6650
# 6651
# 6652
# 6653
# 6654
# 6655
# 6656
# 6657
# 6658
# 6659
# 6660
# 6661
# 6662
# 6663
# 6664
# 6665
# 6666
# 6667
# 6668
# 6669
# 6670
# 6671
# 6672
# 6673
# 6674
# 6675
# 6676
# 6677
# 6678
# 6679
# 6680
# 6681
# 6682
# 6683
# 6684
# 6685
# 6686
# 6687
# 6688
# 6689
# 6690
# 6691
# 6692
# 6693
# 6694
# 6695
# 6696
# 6697
# 6698
# 6699
# 6700
# 6701
# 6702
# 6703
# 6704
# 6705
# 6706
# 6707
# 6708
# 6709
# 6710
# 6711
# 6712
# 6713
# 6714
# 6715
# 6716
# 6717
# 6718
# 6719
# 6720
# 6721
# 6722
# 6723
# 6724
# 6725
# 6726
# 6727
# 6728
# 6729
# 6730
# 6731
# 6732
# 6733
# 6734
# 6735
# 6736
# 6737
# 6738
# 6739
# 6740
# 6741
# 6742
# 6743
# 6744
# 6745
# 6746
# 6747
# 6748
# 6749
# 6750
# 6751
# 6752
# 6753
# 6754
# 6755
# 6756
# 6757
# 6758
# 6759
# 6760
# 6761
# 6762
# 6763
# 6764
# 6765
# 6766
# 6767
# 6768
# 6769
# 6770
# 6771
# 6772
# 6773
# 6774
# 6775
# 6776
# 6777
# 6778
# 6779
# 6780
# 6781
# 6782
# 6783
# 6784
# 6785
# 6786
# 6787
# 6788
# 6789
# 6790
# 6791
# 6792
# 6793
# 6794
# 6795
# 6796
# 6797
# 6798
# 6799
# 6800
# 6801
# 6802
# 6803
# 6804
# 6805
# 6806
# 6807
# 6808
# 6809
# 6810
# 6811
# 6812
# 6813
# 6814
# 6815
# 6816
# 6817
# 6818
# 6819
# 6820
# 6821
# 6822
# 6823
# 6824
# 6825
# 6826
# 6827
# 6828
# 6829
# 6830
# 6831
# 6832
# 6833
# 6834
# 6835
# 6836
# 6837
# 6838
# 6839
# 6840
# 6841
# 6842
# 6843
# 6844
# 6845
# 6846
# 6847
# 6848
# 6849
# 6850
# 6851
# 6852
# 6853
# 6854
# 6855
# 6856
# 6857
# 6858
# 6859
# 6860
# 6861
# 6862
# 6863
# 6864
# 6865
# 6866
# 6867
# 6868
# 6869
# 6870
# 6871
# 6872
# 6873
# 6874
# 6875
# 6876
# 6877
# 6878
# 6879
# 6880
# 6881
# 6882
# 6883
# 6884
# 6885
# 6886
# 6887
# 6888
# 6889
# 6890
# 6891
# 6892
# 6893
# 6894
# 6895
# 6896
# 6897
# 6898
# 6899
# 6900
# 6901
# 6902
# 6903
# 6904
# 6905
# 6906
# 6907
# 6908
# 6909
# 6910
# 6911
# 6912
# 6913
# 6914
# 6915
# 6916
# 6917
# 6918
# 6919
# 6920
# 6921
# 6922
# 6923
# 6924
# 6925
# 6926
# 6927
# 6928
# 6929
# 6930
# 6931
# 6932
# 6933
# 6934
# 6935
# 6936
# 6937
# 6938
# 6939
# 6940
# 6941
# 6942
# 6943
# 6944
# 6945
# 6946
# 6947
# 6948
# 6949
# 6950
# 6951
# 6952
# 6953
# 6954
# 6955
# 6956
# 6957
# 6958
# 6959
# 6960
# 6961
# 6962
# 6963
# 6964
# 6965
# 6966
# 6967
# 6968
# 6969
# 6970
# 6971
# 6972
# 6973
# 6974
# 6975
# 6976
# 6977
# 6978
# 6979
# 6980
# 6981
# 6982
# 6983
# 6984
# 6985
# 6986
# 6987
# 6988
# 6989
# 6990
# 6991
# 6992
# 6993
# 6994
# 6995
# 6996
# 6997
# 6998
# 6999
# 7000
# 7001
# 7002
# 7003
# 7004
# 7005
# 7006
# 7007
# 7008
# 7009
# 7010
# 7011
# 7012
# 7013
# 7014
# 7015
# 7016
# 7017
# 7018
# 7019
# 7020
# 7021
# 7022
# 7023
# 7024
# 7025
# 7026
# 7027
# 7028
# 7029
# 7030
# 7031
# 7032
# 7033
# 7034
# 7035
# 7036
# 7037
# 7038
# 7039
# 7040
# 7041
# 7042
# 7043
# 7044
# 7045
# 7046
# 7047
# 7048
# 7049
# 7050
# 7051
# 7052
# 7053
# 7054
# 7055
# 7056
# 7057
# 7058
# 7059
# 7060
# 7061
# 7062
# 7063
# 7064
# 7065
# 7066
# 7067
# 7068
# 7069
# 7070
# 7071
# 7072
# 7073
# 7074
# 7075
# 7076
# 7077
# 7078
# 7079
# 7080
# 7081
# 7082
# 7083
# 7084
# 7085
# 7086
# 7087
# 7088
# 7089
# 7090
# 7091
# 7092
# 7093
# 7094
# 7095
# 7096
# 7097
# 7098
# 7099
# 7100
# 7101
# 7102
# 7103
# 7104
# 7105
# 7106
# 7107
# 7108
# 7109
# 7110
# 7111
# 7112
# 7113
# 7114
# 7115
# 7116
# 7117
# 7118
# 7119
# 7120
# 7121
# 7122
# 7123
# 7124
# 7125
# 7126
# 7127
# 7128
# 7129
# 7130
# 7131
# 7132
# 7133
# 7134
# 7135
# 7136
# 7137
# 7138
# 7139
# 7140
# 7141
# 7142
# 7143
# 7144
# 7145
# 7146
# 7147
# 7148
# 7149
# 7150
# 7151
# 7152
# 7153
# 7154
# 7155
# 7156
# 7157
# 7158
# 7159
# 7160
# 7161
# 7162
# 7163
# 7164
# 7165
# 7166
# 7167
# 7168
# 7169
# 7170
# 7171
# 7172
# 7173
# 7174
# 7175
# 7176
# 7177
# 7178
# 7179
# 7180
# 7181
# 7182
# 7183
# 7184
# 7185
# 7186
# 7187
# 7188
# 7189
# 7190
# 7191
# 7192
# 7193
# 7194
# 7195
# 7196
# 7197
# 7198
# 7199
# 7200
# 7201
# 7202
# 7203
# 7204
# 7205
# 7206
# 7207
# 7208
# 7209
# 7210
# 7211
# 7212
# 7213
# 7214
# 7215
# 7216
# 7217
# 7218
# 7219
# 7220
# 7221
# 7222
# 7223
# 7224
# 7225
# 7226
# 7227
# 7228
# 7229
# 7230
# 7231
# 7232
# 7233
# 7234
# 7235
# 7236
# 7237
# 7238
# 7239
# 7240
# 7241
# 7242
# 7243
# 7244
# 7245
# 7246
# 7247
# 7248
# 7249
# 7250
# 7251
# 7252
# 7253
# 7254
# 7255
# 7256
# 7257
# 7258
# 7259
# 7260
# 7261
# 7262
# 7263
# 7264
# 7265
# 7266
# 7267
# 7268
# 7269
# 7270
# 7271
# 7272
# 7273
# 7274
# 7275
# 7276
# 7277
# 7278
# 7279
# 7280
# 7281
# 7282
# 7283
# 7284
# 7285
# 7286
# 7287
# 7288
# 7289
# 7290
# 7291
# 7292
# 7293
# 7294
# 7295
# 7296
# 7297
# 7298
# 7299
# 7300
# 7301
# 7302
# 7303
# 7304
# 7305
# 7306
# 7307
# 7308
# 7309
# 7310
# 7311
# 7312
# 7313
# 7314
# 7315
# 7316
# 7317
# 7318
# 7319
# 7320
# 7321
# 7322
# 7323
# 7324
# 7325
# 7326
# 7327
# 7328
# 7329
# 7330
# 7331
# 7332
# 7333
# 7334
# 7335
# 7336
# 7337
# 7338
# 7339
# 7340
# 7341
# 7342
# 7343
# 7344
# 7345
# 7346
# 7347
# 7348
# 7349
# 7350
# 7351
# 7352
# 7353
# 7354
# 7355
# 7356
# 7357
# 7358
# 7359
# 7360
# 7361
# 7362
# 7363
# 7364
# 7365
# 7366
# 7367
# 7368
# 7369
# 7370
# 7371
# 7372
# 7373
# 7374
# 7375
# 7376
# 7377
# 7378
# 7379
# 7380
# 7381
# 7382
# 7383
# 7384
# 7385
# 7386
# 7387
# 7388
# 7389
# 7390
# 7391
# 7392
# 7393
# 7394
# 7395
# 7396
# 7397
# 7398
# 7399
# 7400
# 7401
# 7402
# 7403
# 7404
# 7405
# 7406
# 7407
# 7408
# 7409
# 7410
# 7411
# 7412
# 7413
# 7414
# 7415
# 7416
# 7417
# 7418
# 7419
# 7420
# 7421
# 7422
# 7423
# 7424
# 7425
# 7426
# 7427
# 7428
# 7429
# 7430
# 7431
# 7432
# 7433
# 7434
# 7435
# 7436
# 7437
# 7438
# 7439
# 7440
# 7441
# 7442
# 7443
# 7444
# 7445
# 7446
# 7447
# 7448
# 7449
# 7450
# 7451
# 7452
# 7453
# 7454
# 7455
# 7456
# 7457
# 7458
# 7459
# 7460
# 7461
# 7462
# 7463
# 7464
# 7465
# 7466
# 7467
# 7468
# 7469
# 7470
# 7471
# 7472
# 7473
# 7474
# 7475
# 7476
# 7477
# 7478
# 7479
# 7480
# 7481
# 7482
# 7483
# 7484
# 7485
# 7486
# 7487
# 7488
# 7489
# 7490
# 7491
# 7492
# 7493
# 7494
# 7495
# 7496
# 7497
# 7498
# 7499
# 7500
# 7501
# 7502
# 7503
# 7504
# 7505
# 7506
# 7507
# 7508
# 7509
# 7510
# 7511
# 7512
# 7513
# 7514
# 7515
# 7516
# 7517
# 7518
# 7519
# 7520
# 7521
# 7522
# 7523
# 7524
# 7525
# 7526
# 7527
# 7528
# 7529
# 7530
# 7531
# 7532
# 7533
# 7534
# 7535
# 7536
# 7537
# 7538
# 7539
# 7540
# 7541
# 7542
# 7543
# 7544
# 7545
# 7546
# 7547
# 7548
# 7549
# 7550
# 7551
# 7552
# 7553
# 7554
# 7555
# 7556
# 7557
# 7558
# 7559
# 7560
# 7561
# 7562
# 7563
# 7564
# 7565
# 7566
# 7567
# 7568
# 7569
# 7570
# 7571
# 7572
# 7573
# 7574
# 7575
# 7576
# 7577
# 7578
# 7579
# 7580
# 7581
# 7582
# 7583
# 7584
# 7585
# 7586
# 7587
# 7588
# 7589
# 7590
# 7591
# 7592
# 7593
# 7594
# 7595
# 7596
# 7597
# 7598
# 7599
# 7600
# 7601
# 7602
# 7603
# 7604
# 7605
# 7606
# 7607
# 7608
# 7609
# 7610
# 7611
# 7612
# 7613
# 7614
# 7615
# 7616
# 7617
# 7618
# 7619
# 7620
# 7621
# 7622
# 7623
# 7624
# 7625
# 7626
# 7627
# 7628
# 7629
# 7630
# 7631
# 7632
# 7633
# 7634
# 7635
# 7636
# 7637
# 7638
# 7639
# 7640
# 7641
# 7642
# 7643
# 7644
# 7645
# 7646
# 7647
# 7648
# 7649
# 7650
# 7651
# 7652
# 7653
# 7654
# 7655
# 7656
# 7657
# 7658
# 7659
# 7660
# 7661
# 7662
# 7663
# 7664
# 7665
# 7666
# 7667
# 7668
# 7669
# 7670
# 7671
# 7672
# 7673
# 7674
# 7675
# 7676
# 7677
# 7678
# 7679
# 7680
# 7681
# 7682
# 7683
# 7684
# 7685
# 7686
# 7687
# 7688
# 7689
# 7690
# 7691
# 7692
# 7693
# 7694
# 7695
# 7696
# 7697
# 7698
# 7699
# 7700
# 7701
# 7702
# 7703
# 7704
# 7705
# 7706
# 7707
# 7708
# 7709
# 7710
# 7711
# 7712
# 7713
# 7714
# 7715
# 7716
# 7717
# 7718
# 7719
# 7720
# 7721
# 7722
# 7723
# 7724
# 7725
# 7726
# 7727
# 7728
# 7729
# 7730
# 7731
# 7732
# 7733
# 7734
# 7735
# 7736
# 7737
# 7738
# 7739
# 7740
# 7741
# 7742
# 7743
# 7744
# 7745
# 7746
# 7747
# 7748
# 7749
# 7750
# 7751
# 7752
# 7753
# 7754
# 7755
# 7756
# 7757
# 7758
# 7759
# 7760
# 7761
# 7762
# 7763
# 7764
# 7765
# 7766
# 7767
# 7768
# 7769
# 7770
# 7771
# 7772
# 7773
# 7774
# 7775
# 7776
# 7777
# 7778
# 7779
# 7780
# 7781
# 7782
# 7783
# 7784
# 7785
# 7786
# 7787
# 7788
# 7789
# 7790
# 7791
# 7792
# 7793
# 7794
# 7795
# 7796
# 7797
# 7798
# 7799
# 7800
# 7801
# 7802
# 7803
# 7804
# 7805
# 7806
# 7807
# 7808
# 7809
# 7810
# 7811
# 7812
# 7813
# 7814
# 7815
# 7816
# 7817
# 7818
# 7819
# 7820
# 7821
# 7822
# 7823
# 7824
# 7825
# 7826
# 7827
# 7828
# 7829
# 7830
# 7831
# 7832
# 7833
# 7834
# 7835
# 7836
# 7837
# 7838
# 7839
# 7840
# 7841
# 7842
# 7843
# 7844
# 7845
# 7846
# 7847
# 7848
# 7849
# 7850
# 7851
# 7852
# 7853
# 7854
# 7855
# 7856
# 7857
# 7858
# 7859
# 7860
# 7861
# 7862
# 7863
# 7864
# 7865
# 7866
# 7867
# 7868
# 7869
# 7870
# 7871
# 7872
# 7873
# 7874
# 7875
# 7876
# 7877
# 7878
# 7879
# 7880
# 7881
# 7882
# 7883
# 7884
# 7885
# 7886
# 7887
# 7888
# 7889
# 7890
# 7891
# 7892
# 7893
# 7894
# 7895
# 7896
# 7897
# 7898
# 7899
# 7900
# 7901
# 7902
# 7903
# 7904
# 7905
# 7906
# 7907
# 7908
# 7909
# 7910
# 7911
# 7912
# 7913
# 7914
# 7915
# 7916
# 7917
# 7918
# 7919
# 7920
# 7921
# 7922
# 7923
# 7924
# 7925
# 7926
# 7927
# 7928
# 7929
# 7930
# 7931
# 7932
# 7933
# 7934
# 7935
# 7936
# 7937
# 7938
# 7939
# 7940
# 7941
# 7942
# 7943
# 7944
# 7945
# 7946
# 7947
# 7948
# 7949
# 7950
# 7951
# 7952
# 7953
# 7954
# 7955
# 7956
# 7957
# 7958
# 7959
# 7960
# 7961
# 7962
# 7963
# 7964
# 7965
# 7966
# 7967
# 7968
# 7969
# 7970
# 7971
# 7972
# 7973
# 7974
# 7975
# 7976
# 7977
# 7978
# 7979
# 7980
# 7981
# 7982
# 7983
# 7984
# 7985
# 7986
# 7987
# 7988
# 7989
# 7990
# 7991
# 7992
# 7993
# 7994
# 7995
# 7996
# 7997
# 7998
# 7999
# 8000
# 8001
# 8002
# 8003
# 8004
# 8005
# 8006
# 8007
# 8008
# 8009
# 8010
# 8011
# 8012
# 8013
# 8014
# 8015
# 8016
# 8017
# 8018
# 8019
# 8020
# 8021
# 8022
# 8023
# 8024
# 8025
# 8026
# 8027
# 8028
# 8029
# 8030
# 8031
# 8032
# 8033
# 8034
# 8035
# 8036
# 8037
# 8038
# 8039
# 8040
# 8041
# 8042
# 8043
# 8044
# 8045
# 8046
# 8047
# 8048
# 8049
# 8050
# 8051
# 8052
# 8053
# 8054
# 8055
# 8056
# 8057
# 8058
# 8059
# 8060
# 8061
# 8062
# 8063
# 8064
# 8065
# 8066
# 8067
# 8068
# 8069
# 8070
# 8071
# 8072
# 8073
# 8074
# 8075
# 8076
# 8077
# 8078
# 8079
# 8080
# 8081
# 8082
# 8083
# 8084
# 8085
# 8086
# 8087
# 8088
# 8089
# 8090
# 8091
# 8092
# 8093
# 8094
# 8095
# 8096
# 8097
# 8098
# 8099
# 8100
# 8101
# 8102
# 8103
# 8104
# 8105
# 8106
# 8107
# 8108
# 8109
# 8110
# 8111
# 8112
# 8113
# 8114
# 8115
# 8116
# 8117
# 8118
# 8119
# 8120
# 8121
# 8122
# 8123
# 8124
# 8125
# 8126
# 8127
# 8128
# 8129
# 8130
# 8131
# 8132
# 8133
# 8134
# 8135
# 8136
# 8137
# 8138
# 8139
# 8140
# 8141
# 8142
# 8143
# 8144
# 8145
# 8146
# 8147
# 8148
# 8149
# 8150
# 8151
# 8152
# 8153
# 8154
# 8155
# 8156
# 8157
# 8158
# 8159
# 8160
# 8161
# 8162
# 8163
# 8164
# 8165
# 8166
# 8167
# 8168
# 8169
# 8170
# 8171
# 8172
# 8173
# 8174
# 8175
# 8176
# 8177
# 8178
# 8179
# 8180
# 8181
# 8182
# 8183
# 8184
# 8185
# 8186
# 8187
# 8188
# 8189
# 8190
# 8191
# 8192
# 8193
# 8194
# 8195
# 8196
# 8197
# 8198
# 8199
# 8200
# 8201
# 8202
# 8203
# 8204
# 8205
# 8206
# 8207
# 8208
# 8209
# 8210
# 8211
# 8212
# 8213
# 8214
# 8215
# 8216
# 8217
# 8218
# 8219
# 8220
# 8221
# 8222
# 8223
# 8224
# 8225
# 8226
# 8227
# 8228
# 8229
# 8230
# 8231
# 8232
# 8233
# 8234
# 8235
# 8236
# 8237
# 8238
# 8239
# 8240
# 8241
# 8242
# 8243
# 8244
# 8245
# 8246
# 8247
# 8248
# 8249
# 8250
# 8251
# 8252
# 8253
# 8254
# 8255
# 8256
# 8257
# 8258
# 8259
# 8260
# 8261
# 8262
# 8263
# 8264
# 8265
# 8266
# 8267
# 8268
# 8269
# 8270
# 8271
# 8272
# 8273
# 8274
# 8275
# 8276
# 8277
# 8278
# 8279
# 8280
# 8281
# 8282
# 8283
# 8284
# 8285
# 8286
# 8287
# 8288
# 8289
# 8290
# 8291
# 8292
# 8293
# 8294
# 8295
# 8296
# 8297
# 8298
# 8299
# 8300
# 8301
# 8302
# 8303
# 8304
# 8305
# 8306
# 8307
# 8308
# 8309
# 8310
# 8311
# 8312
# 8313
# 8314
# 8315
# 8316
# 8317
# 8318
# 8319
# 8320
# 8321
# 8322
# 8323
# 8324
# 8325
# 8326
# 8327
# 8328
# 8329
# 8330
# 8331
# 8332
# 8333
# 8334
# 8335
# 8336
# 8337
# 8338
# 8339
# 8340
# 8341
# 8342
# 8343
# 8344
# 8345
# 8346
# 8347
# 8348
# 8349
# 8350
# 8351
# 8352
# 8353
# 8354
# 8355
# 8356
# 8357
# 8358
# 8359
# 8360
# 8361
# 8362
# 8363
# 8364
# 8365
# 8366
# 8367
# 8368
# 8369
# 8370
# 8371
# 8372
# 8373
# 8374
# 8375
# 8376
# 8377
# 8378
# 8379
# 8380
# 8381
# 8382
# 8383
# 8384
# 8385
# 8386
# 8387
# 8388
# 8389
# 8390
# 8391
# 8392
# 8393
# 8394
# 8395
# 8396
# 8397
# 8398
# 8399
# 8400
# 8401
# 8402
# 8403
# 8404
# 8405
# 8406
# 8407
# 8408
# 8409
# 8410
# 8411
# 8412
# 8413
# 8414
# 8415
# 8416
# 8417
# 8418
# 8419
# 8420
# 8421
# 8422
# 8423
# 8424
# 8425
# 8426
# 8427
# 8428
# 8429
# 8430
# 8431
# 8432
# 8433
# 8434
# 8435
# 8436
# 8437
# 8438
# 8439
# 8440
# 8441
# 8442
# 8443
# 8444
# 8445
# 8446
# 8447
# 8448
# 8449
# 8450
# 8451
# 8452
# 8453
# 8454
# 8455
# 8456
# 8457
# 8458
# 8459
# 8460
# 8461
# 8462
# 8463
# 8464
# 8465
# 8466
# 8467
# 8468
# 8469
# 8470
# 8471
# 8472
# 8473
# 8474
# 8475
# 8476
# 8477
# 8478
# 8479
# 8480
# 8481
# 8482
# 8483
# 8484
# 8485
# 8486
# 8487
# 8488
# 8489
# 8490
# 8491
# 8492
# 8493
# 8494
# 8495
# 8496
# 8497
# 8498
# 8499
# 8500
# 8501
# 8502
# 8503
# 8504
# 8505
# 8506
# 8507
# 8508
# 8509
# 8510
# 8511
# 8512
# 8513
# 8514
# 8515
# 8516
# 8517
# 8518
# 8519
# 8520
# 8521
# 8522
# 8523
# 8524
# 8525
# 8526
# 8527
# 8528
# 8529
# 8530
# 8531
# 8532
# 8533
# 8534
# 8535
# 8536
# 8537
# 8538
# 8539
# 8540
# 8541
# 8542
# 8543
# 8544
# 8545
# 8546
# 8547
# 8548
# 8549
# 8550
# 8551
# 8552
# 8553
# 8554
# 8555
# 8556
# 8557
# 8558
# 8559
# 8560
# 8561
# 8562
# 8563
# 8564
# 8565
# 8566
# 8567
# 8568
# 8569
# 8570
# 8571
# 8572
# 8573
# 8574
# 8575
# 8576
# 8577
# 8578
# 8579
# 8580
# 8581
# 8582
# 8583
# 8584
# 8585
# 8586
# 8587
# 8588
# 8589
# 8590
# 8591
# 8592
# 8593
# 8594
# 8595
# 8596
# 8597
# 8598
# 8599
# 8600
# 8601
# 8602
# 8603
# 8604
# 8605
# 8606
# 8607
# 8608
# 8609
# 8610
# 8611
# 8612
# 8613
# 8614
# 8615
# 8616
# 8617
# 8618
# 8619
# 8620
# 8621
# 8622
# 8623
# 8624
# 8625
# 8626
# 8627
# 8628
# 8629
# 8630
# 8631
# 8632
# 8633
# 8634
# 8635
# 8636
# 8637
# 8638
# 8639
# 8640
# 8641
# 8642
# 8643
# 8644
# 8645
# 8646
# 8647
# 8648
# 8649
# 8650
# 8651
# 8652
# 8653
# 8654
# 8655
# 8656
# 8657
# 8658
# 8659
# 8660
# 8661
# 8662
# 8663
# 8664
# 8665
# 8666
# 8667
# 8668
# 8669
# 8670
# 8671
# 8672
# 8673
# 8674
# 8675
# 8676
# 8677
# 8678
# 8679
# 8680
# 8681
# 8682
# 8683
# 8684
# 8685
# 8686
# 8687
# 8688
# 8689
# 8690
# 8691
# 8692
# 8693
# 8694
# 8695
# 8696
# 8697
# 8698
# 8699
# 8700
# 8701
# 8702
# 8703
# 8704
# 8705
# 8706
# 8707
# 8708
# 8709
# 8710
# 8711
# 8712
# 8713
# 8714
# 8715
# 8716
# 8717
# 8718
# 8719
# 8720
# 8721
# 8722
# 8723
# 8724
# 8725
# 8726
# 8727
# 8728
# 8729
# 8730
# 8731
# 8732
# 8733
# 8734
# 8735
# 8736
# 8737
# 8738
# 8739
# 8740
# 8741
# 8742
# 8743
# 8744
# 8745
# 8746
# 8747
# 8748
# 8749
# 8750
# 8751
# 8752
# 8753
# 8754
# 8755
# 8756
# 8757
# 8758
# 8759
# 8760
# 8761
# 8762
# 8763
# 8764
# 8765
# 8766
# 8767
# 8768
# 8769
# 8770
# 8771
# 8772
# 8773
# 8774
# 8775
# 8776
# 8777
# 8778
# 8779
# 8780
# 8781
# 8782
# 8783
# 8784
# 8785
# 8786
# 8787
# 8788
# 8789
# 8790
# 8791
# 8792
# 8793
# 8794
# 8795
# 8796
# 8797
# 8798
# 8799
# 8800
# 8801
# 8802
# 8803
# 8804
# 8805
# 8806
# 8807
# 8808
# 8809
# 8810
# 8811
# 8812
# 8813
# 8814
# 8815
# 8816
# 8817
# 8818
# 8819
# 8820
# 8821
# 8822
# 8823
# 8824
# 8825
# 8826
# 8827
# 8828
# 8829
# 8830
# 8831
# 8832
# 8833
# 8834
# 8835
# 8836
# 8837
# 8838
# 8839
# 8840
# 8841
# 8842
# 8843
# 8844
# 8845
# 8846
# 8847
# 8848
# 8849
# 8850
# 8851
# 8852
# 8853
# 8854
# 8855
# 8856
# 8857
# 8858
# 8859
# 8860
# 8861
# 8862
# 8863
# 8864
# 8865
# 8866
# 8867
# 8868
# 8869
# 8870
# 8871
# 8872
# 8873
# 8874
# 8875
# 8876
# 8877
# 8878
# 8879
# 8880
# 8881
# 8882
# 8883
# 8884
# 8885
# 8886
# 8887
# 8888
# 8889
# 8890
# 8891
# 8892
# 8893
# 8894
# 8895
# 8896
# 8897
# 8898
# 8899
# 8900
# 8901
# 8902
# 8903
# 8904
# 8905
# 8906
# 8907
# 8908
# 8909
# 8910
# 8911
# 8912
# 8913
# 8914
# 8915
# 8916
# 8917
# 8918
# 8919
# 8920
# 8921
# 8922
# 8923
# 8924
# 8925
# 8926
# 8927
# 8928
# 8929
# 8930
# 8931
# 8932
# 8933
# 8934
# 8935
# 8936
# 8937
# 8938
# 8939
# 8940
# 8941
# 8942
# 8943
# 8944
# 8945
# 8946
# 8947
# 8948
# 8949
# 8950
# 8951
# 8952
# 8953
# 8954
# 8955
# 8956
# 8957
# 8958
# 8959
# 8960
# 8961
# 8962
# 8963
# 8964
# 8965
# 8966
# 8967
# 8968
# 8969
# 8970
# 8971
# 8972
# 8973
# 8974
# 8975
# 8976
# 8977
# 8978
# 8979
# 8980
# 8981
# 8982
# 8983
# 8984
# 8985
# 8986
# 8987
# 8988
# 8989
# 8990
# 8991
# 8992
# 8993
# 8994
# 8995
# 8996
# 8997
# 8998
# 8999
# 9000
# 9001
# 9002
# 9003
# 9004
# 9005
# 9006
# 9007
# 9008
# 9009
# 9010
# 9011
# 9012
# 9013
# 9014
# 9015
# 9016
# 9017
# 9018
# 9019
# 9020
# 9021
# 9022
# 9023
# 9024
# 9025
# 9026
# 9027
# 9028
# 9029
# 9030
# 9031
# 9032
# 9033
# 9034
# 9035
# 9036
# 9037
# 9038
# 9039
# 9040
# 9041
# 9042
# 9043
# 9044
# 9045
# 9046
# 9047
# 9048
# 9049
# 9050
# 9051
# 9052
# 9053
# 9054
# 9055
# 9056
# 9057
# 9058
# 9059
# 9060
# 9061
# 9062
# 9063
# 9064
# 9065
# 9066
# 9067
# 9068
# 9069
# 9070
# 9071
# 9072
# 9073
# 9074
# 9075
# 9076
# 9077
# 9078
# 9079
# 9080
# 9081
# 9082
# 9083
# 9084
# 9085
# 9086
# 9087
# 9088
# 9089
# 9090
# 9091
# 9092
# 9093
# 9094
# 9095
# 9096
# 9097
# 9098
# 9099
# 9100
# 9101
# 9102
# 9103
# 9104
# 9105
# 9106
# 9107
# 9108
# 9109
# 9110
# 9111
# 9112
# 9113
# 9114
# 9115
# 9116
# 9117
# 9118
# 9119
# 9120
# 9121
# 9122
# 9123
# 9124
# 9125
# 9126
# 9127
# 9128
# 9129
# 9130
# 9131
# 9132
# 9133
# 9134
# 9135
# 9136
# 9137
# 9138
# 9139
# 9140
# 9141
# 9142
# 9143
# 9144
# 9145
# 9146
# 9147
# 9148
# 9149
# 9150
# 9151
# 9152
# 9153
# 9154
# 9155
# 9156
# 9157
# 9158
# 9159
# 9160
# 9161
# 9162
# 9163
# 9164
# 9165
# 9166
# 9167
# 9168
# 9169
# 9170
# 9171
# 9172
# 9173
# 9174
# 9175
# 9176
# 9177
# 9178
# 9179
# 9180
# 9181
# 9182
# 9183
# 9184
# 9185
# 9186
# 9187
# 9188
# 9189
# 9190
# 9191
# 9192
# 9193
# 9194
# 9195
# 9196
# 9197
# 9198
# 9199
# 9200
# 9201
# 9202
# 9203
# 9204
# 9205
# 9206
# 9207
# 9208
# 9209
# 9210
# 9211
# 9212
# 9213
# 9214
# 9215
# 9216
# 9217
# 9218
# 9219
# 9220
# 9221
# 9222
# 9223
# 9224
# 9225
# 9226
# 9227
# 9228
# 9229
# 9230
# 9231
# 9232
# 9233
# 9234
# 9235
# 9236
# 9237
# 9238
# 9239
# 9240
# 9241
# 9242
# 9243
# 9244
# 9245
# 9246
# 9247
# 9248
# 9249
# 9250
# 9251
# 9252
# 9253
# 9254
# 9255
# 9256
# 9257
# 9258
# 9259
# 9260
# 9261
# 9262
# 9263
# 9264
# 9265
# 9266
# 9267
# 9268
# 9269
# 9270
# 9271
# 9272
# 9273
# 9274
# 9275
# 9276
# 9277
# 9278
# 9279
# 9280
# 9281
# 9282
# 9283
# 9284
# 9285
# 9286
# 9287
# 9288
# 9289
# 9290
# 9291
# 9292
# 9293
# 9294
# 9295
# 9296
# 9297
# 9298
# 9299
# 9300
# 9301
# 9302
# 9303
# 9304
# 9305
# 9306
# 9307
# 9308
# 9309
# 9310
# 9311
# 9312
# 9313
# 9314
# 9315
# 9316
# 9317
# 9318
# 9319
# 9320
# 9321
# 9322
# 9323
# 9324
# 9325
# 9326
# 9327
# 9328
# 9329
# 9330
# 9331
# 9332
# 9333
# 9334
# 9335
# 9336
# 9337
# 9338
# 9339
# 9340
# 9341
# 9342
# 9343
# 9344
# 9345
# 9346
# 9347
# 9348
# 9349
# 9350
# 9351
# 9352
# 9353
# 9354
# 9355
# 9356
# 9357
# 9358
# 9359
# 9360
# 9361
# 9362
# 9363
# 9364
# 9365
# 9366
# 9367
# 9368
# 9369
# 9370
# 9371
# 9372
# 9373
# 9374
# 9375
# 9376
# 9377
# 9378
# 9379
# 9380
# 9381
# 9382
# 9383
# 9384
# 9385
# 9386
# 9387
# 9388
# 9389
# 9390
# 9391
# 9392
# 9393
# 9394
# 9395
# 9396
# 9397
# 9398
# 9399
# 9400
# 9401
# 9402
# 9403
# 9404
# 9405
# 9406
# 9407
# 9408
# 9409
# 9410
# 9411
# 9412
# 9413
# 9414
# 9415
# 9416
# 9417
# 9418
# 9419
# 9420
# 9421
# 9422
# 9423
# 9424
# 9425
# 9426
# 9427
# 9428
# 9429
# 9430
# 9431
# 9432
# 9433
# 9434
# 9435
# 9436
# 9437
# 9438
# 9439
# 9440
# 9441
# 9442
# 9443
# 9444
# 9445
# 9446
# 9447
# 9448
# 9449
# 9450
# 9451
# 9452
# 9453
# 9454
# 9455
# 9456
# 9457
# 9458
# 9459
# 9460
# 9461
# 9462
# 9463
# 9464
# 9465
# 9466
# 9467
# 9468
# 9469
# 9470
# 9471
# 9472
# 9473
# 9474
# 9475
# 9476
# 9477
# 9478
# 9479
# 9480
# 9481
# 9482
# 9483
# 9484
# 9485
# 9486
# 9487
# 9488
# 9489
# 9490
# 9491
# 9492
# 9493
# 9494
# 9495
# 9496
# 9497
# 9498
# 9499
# 9500
# 9501
# 9502
# 9503
# 9504
# 9505
# 9506
# 9507
# 9508
# 9509
# 9510
# 9511
# 9512
# 9513
# 9514
# 9515
# 9516
# 9517
# 9518
# 9519
# 9520
# 9521
# 9522
# 9523
# 9524
# 9525
# 9526
# 9527
# 9528
# 9529
# 9530
# 9531
# 9532
# 9533
# 9534
# 9535
# 9536
# 9537
# 9538
# 9539
# 9540
# 9541
# 9542
# 9543
# 9544
# 9545
# 9546
# 9547
# 9548
# 9549
# 9550
# 9551
# 9552
# 9553
# 9554
# 9555
# 9556
# 9557
# 9558
# 9559
# 9560
# 9561
# 9562
# 9563
# 9564
# 9565
# 9566
# 9567
# 9568
# 9569
# 9570
# 9571
# 9572
# 9573
# 9574
# 9575
# 9576
# 9577
# 9578
# 9579
# 9580
# 9581
# 9582
# 9583
# 9584
# 9585
# 9586
# 9587
# 9588
# 9589
# 9590
# 9591
# 9592
# 9593
# 9594
# 9595
# 9596
# 9597
# 9598
# 9599
# 9600
# 9601
# 9602
# 9603
# 9604
# 9605
# 9606
# 9607
# 9608
# 9609
# 9610
# 9611
# 9612
# 9613
# 9614
# 9615
# 9616
# 9617
# 9618
# 9619
# 9620
# 9621
# 9622
# 9623
# 9624
# 9625
# 9626
# 9627
# 9628
# 9629
# 9630
# 9631
# 9632
# 9633
# 9634
# 9635
# 9636
# 9637
# 9638
# 9639
# 9640
# 9641
# 9642
# 9643
# 9644
# 9645
# 9646
# 9647
# 9648
# 9649
# 9650
# 9651
# 9652
# 9653
# 9654
# 9655
# 9656
# 9657
# 9658
# 9659
# 9660
# 9661
# 9662
# 9663
# 9664
# 9665
# 9666
# 9667
# 9668
# 9669
# 9670
# 9671
# 9672
# 9673
# 9674
# 9675
# 9676
# 9677
# 9678

# %% [markdown]
# ### Tokenize the data
#
#
# Let's vectorize the texts we collected, and prepare a training and validation split.
# We will merely be using the concepts we introduced earlier in this section.
#
# Because pre-trained word embeddings are meant to be particularly useful on problems where little training data is available (otherwise,
# task-specific embeddings are likely to outperform them), we will add the following twist: we restrict the training data to its first 200
# samples. So we will be learning to classify movie reviews after looking at just 200 examples...

# %%
from keras.preprocessing.text import Tokenizer
#from keras.preprocessing.sequence import pad_sequences
import numpy as np

maxlen = 300  # We will cut reviews after 100 words
training_samples = 150  # We will be training on X samples
validation_samples = 51  # We will be validating on X samples
max_words = 10000  # We will only consider the top 10,000 words in the dataset

# we will use training_samples and validation_samples
# later on in a few cells... for splitting data...

# %%
# link: https://keras.io/preprocessing/text/
# has good details on what a tokenizer does

# This class allows to vectorize a text corpus, by turning each text into either a sequence of integers
# omits common characters
tokenizer = Tokenizer(num_words=max_words)

# fit_on_texts means it learns the indices of the words
tokenizer.fit_on_texts(texts)

# the sequences are comprised of those indices
sequences = tokenizer.texts_to_sequences(texts)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

# in case of low word counts, we need to pad sequences
# so that they are uniform length
data = pad_sequences(sequences, maxlen=maxlen)

# our labels, which were previously stored as a list [],
# are now converted to a numpy array for modeling
labels = np.asarray(labels)
print('Shape of data tensor:', data.shape)
print('Shape of label tensor:', labels.shape)
# Out:
# Found 72633 unique tokens.
# Shape of data tensor: (17243, 300)
# Shape of label tensor: (17243,)

# %%
# Split the data into a training set and a validation set
# But first, shuffle the data, since we started from data
# where sample are ordered (all negative first, then all positive).
indices = np.arange(data.shape[0])
np.random.shuffle(indices)
data = data[indices]
labels = labels[indices]

x_train = data[:training_samples] # from 0 to (200) training samples
y_train = labels[:training_samples]
x_val = data[training_samples: training_samples + validation_samples]
y_val = labels[training_samples: training_samples + validation_samples]

# %% [markdown]
# ### Download the GloVe word embeddings
#
#
# Head to `https://nlp.stanford.edu/projects/glove/` (where you can learn more about the GloVe algorithm), and download the pre-computed
# embeddings from 2014 English Wikipedia. It's a 822MB zip file named `glove.6B.zip`, containing 100-dimensional embedding vectors for
# 400,000 words (or non-word tokens). Un-zip it.

# %% [markdown]
# ### Pre-process the embeddings
#
#
# Let's parse the un-zipped file (it's a `txt` file) to build an index mapping words (as strings) to their vector representation (as number
# vectors).

# %%
# https://drive.google.com/file/d/1OZ9fiJCZV1mIpGvw_mS4ZJKZS-QaoJ5S/view?usp=sharing
# !gdown 1OZ9fiJCZV1mIpGvw_mS4ZJKZS-QaoJ5S
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1OZ9fiJCZV1mIpGvw_mS4ZJKZS-QaoJ5S
# From (redirected): https://drive.google.com/uc?id=1OZ9fiJCZV1mIpGvw_mS4ZJKZS-QaoJ5S&confirm=t&uuid=351c325e-446b-4987-b5fe-b1f8133b2058
# To: /content/glove.6B.100d.txt
# 100% 347M/347M [00:05<00:00, 67.1MB/s]

# %%
import numpy as np
glove_dir = '/content/'

embeddings_index = {}
f = open(os.path.join(glove_dir, 'glove.6B.100d.txt'))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %% [markdown]
# Now let's build an embedding matrix that we will be able to load into an `Embedding` layer. It must be a matrix of shape `(max_words,
# embedding_dim)`, where each entry `i` contains the `embedding_dim`-dimensional vector for the word of index `i` in our reference word index
# (built during tokenization). Note that the index `0` is not supposed to stand for any word or token -- it's a placeholder.

# %%
embedding_dim = 100 # this is the dimension of the file we imported
# could use 50, but need to make sure you download that file!

embedding_matrix = np.zeros((max_words, embedding_dim))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if i < max_words:
        if embedding_vector is not None:
            # Words not found in embedding index will be all-zeros.
            embedding_matrix[i] = embedding_vector

# %% [markdown]
# ### Define a model
#
# We will be using the same model architecture as before:

# %%
from keras.models import Sequential
from keras.layers import Embedding, Flatten, Dense

model = Sequential()
model.add(Embedding(max_words, embedding_dim, input_length=maxlen))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()

# in this model, the embeddings are turned on their sides
# when they get flattened, so our 100 words with
# 100 dimensions turns into 10000 features for modeling

# if you adjust the values for embedding_dim (make it 20?)
# and max_words (make it 30?),
# this may help you better understand things...
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 300, 100)          1000000
#
#  flatten_4 (Flatten)         (None, 30000)             0
#
#  dense_6 (Dense)             (None, 32)                960032
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1,960,065
# Trainable params: 1,960,065
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Load the GloVe embeddings in the model
#
#
# The `Embedding` layer has a single weight matrix: a 2D float matrix where each entry `i` is the word vector meant to be associated with
# index `i`. Simple enough. Let's just load the GloVe matrix we prepared into our `Embedding` layer, the first layer in our model:

# %%
model.layers[0].set_weights([embedding_matrix])
model.layers[0].trainable = False

# %% [markdown]
# Additionally, we freeze the embedding layer (we set its `trainable` attribute to `False`), following the same rationale as what you are
# already familiar with in the context of pre-trained convnet features: when parts of a model are pre-trained (like our `Embedding` layer),
# and parts are randomly initialized (like our classifier), the pre-trained parts should not be updated during training to avoid forgetting
# what they already know. The large gradient update triggered by the randomly initialized layers would be very disruptive to the already
# learned features.

# %% [markdown]
# ### Train and evaluate
#
# Let's compile our model and train it:

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(x_train, y_train,
                    epochs=300,
                    batch_size=5,
                    validation_data=(x_val, y_val))
# saves on left hand side!
model.save_weights('pre_trained_glove_model.h5')
# Out:
# Epoch 1/300
# 30/30 [==============================] - 1s 9ms/step - loss: 1.5641 - acc: 0.6400 - val_loss: 0.9902 - val_acc: 0.8039
# Epoch 2/300
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1962 - acc: 0.9200 - val_loss: 0.9321 - val_acc: 0.7843
# Epoch 3/300
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0528 - acc: 0.9800 - val_loss: 1.2632 - val_acc: 0.7647
# Epoch 4/300
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0650 - acc: 0.9867 - val_loss: 1.2697 - val_acc: 0.8039
# Epoch 5/300
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0022 - acc: 1.0000 - val_loss: 1.3651 - val_acc: 0.8039
# Epoch 6/300
# 30/30 [==============================] - 0s 4ms/step - loss: 6.9301e-04 - acc: 1.0000 - val_loss: 1.3650 - val_acc: 0.8039
# Epoch 7/300
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0130 - acc: 0.9933 - val_loss: 2.3703 - val_acc: 0.8039
# Epoch 8/300
# 30/30 [==============================] - 0s 5ms/step - loss: 3.4848e-04 - acc: 1.0000 - val_loss: 1.7074 - val_acc: 0.8039
# Epoch 9/300
# 30/30 [==============================] - 0s 5ms/step - loss: 1.3573e-04 - acc: 1.0000 - val_loss: 1.4958 - val_acc: 0.8039
# Epoch 10/300
# 30/30 [==============================] - 0s 4ms/step - loss: 3.9370e-05 - acc: 1.0000 - val_loss: 1.5633 - val_acc: 0.7843
# Epoch 11/300
# 30/30 [==============================] - 0s 4ms/step - loss: 1.5243e-05 - acc: 1.0000 - val_loss: 1.8122 - val_acc: 0.8039
# Epoch 12/300
# 30/30 [==============================] - 0s 4ms/step - loss: 6.4883e-06 - acc: 1.0000 - val_loss: 2.0068 - val_acc: 0.8039
# Epoch 13/300
# 30/30 [==============================] - 0s 4ms/step - loss: 3.9932e-06 - acc: 1.0000 - val_loss: 3.0602 - val_acc: 0.8039
# Epoch 14/300
# 30/30 [==============================] - 0s 4ms/step - loss: 7.2079e-05 - acc: 1.0000 - val_loss: 2.0750 - val_acc: 0.7843
# Epoch 15/300
# 30/30 [==============================] - 0s 4ms/step - loss: 5.9234e-07 - acc: 1.0000 - val_loss: 2.2295 - val_acc: 0.8039
# Epoch 16/300
# 30/30 [==============================] - 0s 4ms/step - loss: 2.8014e-07 - acc: 1.0000 - val_loss: 2.2708 - val_acc: 0.8039
# Epoch 17/300
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4711e-07 - acc: 1.0000 - val_loss: 2.3315 - val_acc: 0.8039
# Epoch 18/300
# 30/30 [==============================] - 0s 5ms/step - loss: 7.2410e-08 - acc: 1.0000 - val_loss: 2.3563 - val_acc: 0.8039
# Epoch 19/300
# 30/30 [==============================] - 0s 5ms/step - loss: 3.4116e-08 - acc: 1.0000 - val_loss: 2.5064 - val_acc: 0.8039
# Epoch 20/300
# 30/30 [==============================] - 0s 4ms/step - loss: 1.8529e-08 - acc: 1.0000 - val_loss: 2.4143 - val_acc: 0.8039
# Epoch 21/300
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0305e-08 - acc: 1.0000 - val_loss: 2.5705 - val_acc: 0.8039
# Epoch 22/300
# 30/30 [==============================] - 0s 5ms/step - loss: 7.6053e-09 - acc: 1.0000 - val_loss: 2.6346 - val_acc: 0.8039
# Epoch 23/300
# 30/30 [==============================] - 0s 4ms/step - loss: 6.1640e-09 - acc: 1.0000 - val_loss: 2.5611 - val_acc: 0.8039
# Epoch 24/300
# 30/30 [==============================] - 0s 4ms/step - loss: 4
300
# 30/30 [==============================] - 0s 4ms/step - loss: 3.0547e-09 - acc: 1.0000 - val_loss: 3.3463 - val_acc: 0.8039
# Epoch 297/300
# 30/30 [==============================] - 0s 4ms/step - loss: 3.0846e-09 - acc: 1.0000 - val_loss: 3.3492 - val_acc: 0.8039
# Epoch 298/300
# 30/30 [==============================] - 0s 7ms/step - loss: 3.1112e-09 - acc: 1.0000 - val_loss: 3.3521 - val_acc: 0.8039
# Epoch 299/300
# 30/30 [==============================] - 0s 5ms/step - loss: 3.1416e-09 - acc: 1.0000 - val_loss: 3.3549 - val_acc: 0.8039
# Epoch 300/300
# 30/30 [==============================] - 0s 5ms/step - loss: 3.1725e-09 - acc: 1.0000 - val_loss: 3.3577 - val_acc: 0.8039

# %% [markdown]
# Let's plot its performance over time:

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# We can also try to train the same model without loading the pre-trained word embeddings and without freezing the embedding layer. In that
# case, we would be learning a task-specific embedding of our input tokens, which is generally more powerful than pre-trained word embeddings
# when lots of data is available. However, in our case, we have only 200 training samples. Let's try it:

# %%
from keras.models import Sequential
from keras.layers import Embedding, Flatten, Dense

model = Sequential()
model.add(Embedding(max_words, embedding_dim, input_length=maxlen))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(x_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data=(x_val, y_val))
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 300, 100)          1000000
#
#  flatten_5 (Flatten)         (None, 30000)             0
#
#  dense_8 (Dense)             (None, 32)                960032
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1,960,065
# Trainable params: 1,960,065
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 5/5 [==============================] - 1s 50ms/step - loss: 0.6753 - acc: 0.6800 - val_loss: 0.5435 - val_acc: 0.8039
# Epoch 2/10
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4207 - acc: 0.8200 - val_loss: 0.5244 - val_acc: 0.8039
# Epoch 3/10
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2819 - acc: 0.9200 - val_loss: 0.5127 - val_acc: 0.8039
# Epoch 4/10
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1628 - acc: 0.9667 - val_loss: 0.5089 - val_acc: 0.8039
# Epoch 5/10
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1033 - acc: 0.9867 - val_loss: 0.5108 - val_acc: 0.8039
# Epoch 6/10
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0607 - acc: 1.0000 - val_loss: 0.5098 - val_acc: 0.8039
# Epoch 7/10
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0372 - acc: 1.0000 - val_loss: 0.5330 - val_acc: 0.8039
# Epoch 8/10
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0228 - acc: 1.0000 - val_loss: 0.5949 - val_acc: 0.8039
# Epoch 9/10
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0165 - acc: 1.0000 - val_loss: 0.5805 - val_acc: 0.8039
# Epoch 10/10
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0100 - acc: 1.0000 - val_loss: 0.6027 - val_acc: 0.8039

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# # On your own
# Finally, you can evaluate the model on the test data. First, we will need to tokenize the test data:

# %%
# test_dir = os.path.join(imdb_dir, 'test')

# labels = []
# texts = []

# for label_type in ['neg', 'pos']:
#     dir_name = os.path.join(test_dir, label_type)
#     for fname in sorted(os.listdir(dir_name)):
#         if fname[-4:] == '.txt':
#             f = open(os.path.join(dir_name, fname))
#             texts.append(f.read())
#             f.close()
#             if label_type == 'neg':
#                 labels.append(0)
#             else:
#                 labels.append(1)

# sequences = tokenizer.texts_to_sequences(texts)
# x_test = pad_sequences(sequences, maxlen=maxlen)
# y_test = np.asarray(labels)

# %% [markdown]
# And let's load and evaluate the first model:

# %%
# this model is saved on the left menu
# model.load_weights('pre_trained_glove_model.h5')
# model.evaluate(x_test, y_test)

# %% [markdown]
# We get an appalling test accuracy of 54%. Working with just a handful of training samples is hard!
